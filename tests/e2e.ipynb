# %%
# install requirements
#!pip install numpy pandas scikit-learn matplotlib seaborn

# %%
import sys
import os
sys.path.append(os.path.abspath('../src'))

# %%
# Suppress warnings in this notebook
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Make an experimental design table
# Here the settings for the experiments can be modified in the dictionary called run_settings. Refer to the paper for more details on of each of the parameters.

# %% [markdown]
# ## A less complicated example:

# %%
run_settings = {# level of entropy: min, medium and/or max
                "process_entropy":["min_entropy"], #,"med_entropy","max_entropy"
                
                # number of traces/cases in the event-log
                "number_of_traces":[500],

                # number of activity types
                "statespace_size":[5], 

                # first or higher-order markov chain to represent the transitions
                "process_type":["memoryless"], 
                
                # order of HOMC - only specify this when using process with memory
                "process_memory":[2],
                
                # number of transitions - only used for medium entropy (should be higher than 2 and < statespace size)
                "med_ent_n_transitions":[1,2,3,4,5],
                                
                # lambda parameter of inter-arrival times
                "inter_arrival_time":[1.5],
                
                # lambda parameter of process noise
                "process_stability_scale":[0.1],
                
                # probability of agent being available
                "resource_availability_p":[0.5],

                # number of agents in the process
                "resource_availability_n":[3],

                # waiting time in full days, when no agent is available
                "resource_availability_m":[0.041],
                
                # variation between activity durations
                "activity_duration_lambda_range":[1],
                
                # business hours definition: when can cases be processed? ()
                "Deterministic_offset_W":["weekdays"],

                # time-unit for a full week: days = 7, hrs = 24*7, etc.
                "Deterministic_offset_u":[7],
                
                # training data format (See Verenich et al., 2019): 
                # True - use first event to predict total cycle-time. 
                # False - use Prefix-log format / each event to predict remaining cycle time.
                "first_state_model":[False],

                # offset for the timestamps used (years after 1970)
                "datetime_offset":[45],
                
                # number of repetitions of the experiments: duplicates the experiment table (2 times here)
                "num_replications":list(range(0, 5))
               }


# import the make_design_table function to generate a full factorial experimental design table
from SynBPS.simulation.DoE import make_design_table
df = make_design_table(run_settings, file="design_table.csv")

# inspect the resulting design table
df
# Out:
# saved to design_table.csv
#    process_entropy  number_of_traces  statespace_size process_type  \
# 0      min_entropy             500.0                5   memoryless
# 1      min_entropy             500.0                5   memoryless
# 2      min_entropy             500.0                5   memoryless
# 3      min_entropy             500.0                5   memoryless
# 4      min_entropy             500.0                5   memoryless
# 5      min_entropy             500.0                5   memoryless
# 6      min_entropy             500.0                5   memoryless
# 7      min_entropy             500.0                5   memoryless
# 8      min_entropy             500.0                5   memoryless
# 9      min_entropy             500.0                5   memoryless
# 10     min_entropy             500.0                5   memoryless
# 11     min_entropy             500.0                5   memoryless
# 12     min_entropy             500.0                5   memoryless
# 13     min_entropy             500.0                5   memoryless
# 14     min_entropy             500.0                5   memoryless
# 15     min_entropy             500.0                5   memoryless
# 16     min_entropy             500.0                5   memoryless
# 17     min_entropy             500.0                5   memoryless
# 18     min_entropy             500.0                5   memoryless
# 19     min_entropy             500.0                5   memoryless
# 20     min_entropy             500.0                5   memoryless
# 21     min_entropy             500.0                5   memoryless
# 22     min_entropy             500.0                5   memoryless
# 23     min_entropy             500.0                5   memoryless
# 24     min_entropy             500.0                5   memoryless
#
#     process_memory  med_ent_n_transitions  inter_arrival_time  \
# 0              2.0                    1.0                 1.5
# 1              2.0                    2.0                 1.5
# 2              2.0                    3.0                 1.5
# 3              2.0                    4.0                 1.5
# 4              2.0                    5.0                 1.5
# 5              2.0                    1.0                 1.5
# 6              2.0                    2.0                 1.5
# 7              2.0                    3.0                 1.5
# 8              2.0                    4.0                 1.5
# 9              2.0                    5.0                 1.5
# 10             2.0                    1.0                 1.5
# 11             2.0                    2.0                 1.5
# 12             2.0                    3.0                 1.5
# 13             2.0                    4.0                 1.5
# 14             2.0                    5.0                 1.5
# 15             2.0                    1.0                 1.5
# 16             2.0                    2.0                 1.5
# 17             2.0                    3.0                 1.5
# 18             2.0                    4.0                 1.5
# 19             2.0                    5.0                 1.5
# 20             2.0                    1.0                 1.5
# 21             2.0                    2.0                 1.5
# 22             2.0                    3.0                 1.5
# 23             2.0                    4.0                 1.5
# 24             2.0                    5.0                 1.5
#
#     process_stability_scale  resource_availability_p  resource_availability_n  \
# 0                       0.1                      0.5                      3.0
# 1                       0.1                      0.5                      3.0
# 2                       0.1                      0.5                      3.0
# 3                       0.1                      0.5                      3.0
# 4                       0.1                      0.5                      3.0
# 5                       0.1                      0.5                      3.0
# 6                       0.1                      0.5                      3.0
# 7                       0.1                      0.5                      3.0
# 8                       0.1                      0.5                      3.0
# 9                       0.1                      0.5                      3.0
# 10                      0.1                      0.5                      3.0
# 11                      0.1                      0.5                      3.0
# 12                      0.1                      0.5                      3.0
# 13                      0.1                      0.5                      3.0
# 14                      0.1                      0.5                      3.0
# 15                      0.1                      0.5                      3.0
# 16                      0.1                      0.5                      3.0
# 17                      0.1                      0.5                      3.0
# 18                      0.1                      0.5                      3.0
# 19                      0.1                      0.5                      3.0
# 20                      0.1                      0.5                      3.0
# 21                      0.1                      0.5                      3.0
# 22                      0.1                      0.5                      3.0
# 23                      0.1                      0.5                      3.0
# 24                      0.1                      0.5                      3.0
#
#     resource_availability_m  activity_duration_lambda_range  \
# 0                     0.041                             1.0
# 1                     0.041                             1.0
# 2                     0.041                             1.0
# 3                     0.041                             1.0
# 4                     0.041                             1.0
# 5                     0.041                             1.0
# 6                     0.041                             1.0
# 7                     0.041                             1.0
# 8                     0.041                             1.0
# 9                     0.041                             1.0
# 10                    0.041                             1.0
# 11                    0.041                             1.0
# 12                    0.041                             1.0
# 13                    0.041                             1.0
# 14                    0.041                             1.0
# 15                    0.041                             1.0
# 16                    0.041                             1.0
# 17                    0.041                             1.0
# 18                    0.041                             1.0
# 19                    0.041                             1.0
# 20                    0.041                             1.0
# 21                    0.041                             1.0
# 22                    0.041                             1.0
# 23                    0.041                             1.0
# 24                    0.041                             1.0
#
#    Deterministic_offset_W  Deterministic_offset_u first_state_model  \
# 0                weekdays                     7.0             False
# 1                weekdays                     7.0             False
# 2                weekdays                     7.0             False
# 3                weekdays                     7.0             False
# 4                weekdays                     7.0             False
# 5                weekdays                     7.0             False
# 6                weekdays                     7.0             False
# 7                weekdays                     7.0             False
# 8                weekdays                     7.0             False
# 9                weekdays                     7.0             False
# 10               weekdays                     7.0             False
# 11               weekdays                     7.0             False
# 12               weekdays                     7.0             False
# 13               weekdays                     7.0             False
# 14               weekdays                     7.0             False
# 15               weekdays                     7.0             False
# 16               weekdays                     7.0             False
# 17               weekdays                     7.0             False
# 18               weekdays                     7.0             False
# 19               weekdays                     7.0             False
# 20               weekdays                     7.0             False
# 21               weekdays                     7.0             False
# 22               weekdays                     7.0             False
# 23               weekdays                     7.0             False
# 24               weekdays                     7.0             False
#
#     datetime_offset  num_replications  RUN  Done  Failure
# 0              45.0               0.0    1     0        0
# 1              45.0               0.0    2     0        0
# 2              45.0               0.0    3     0        0
# 3              45.0               0.0    4     0        0
# 4              45.0               0.0    5     0        0
# 5              45.0               1.0    6     0        0
# 6              45.0               1.0    7     0        0
# 7              45.0               1.0    8     0        0
# 8              45.0               1.0    9     0        0
# 9              45.0               1.0   10     0        0
# 10             45.0               2.0   11     0        0
# 11             45.0               2.0   12     0        0
# 12             45.0               2.0   13     0        0
# 13             45.0               2.0   14     0        0
# 14             45.0               2.0   15     0        0
# 15             45.0               3.0   16     0        0
# 16             45.0               3.0   17     0        0
# 17             45.0               3.0   18     0        0
# 18             45.0               3.0   19     0        0
# 19             45.0               3.0   20     0        0
# 20             45.0               4.0   21     0        0
# 21             45.0               4.0   22     0        0
# 22             45.0               4.0   23     0        0
# 23             45.0               4.0   24     0        0
# 24             45.0               4.0   25     0        0

# %% [markdown]
# # Specify Train() and Test() functions
# Before running the experiments, you need to define model training and evaluation functions.
#
# In this example we train a first state model, which is a model using only the first observed event (state) to predict to total cycle-time. The default data preparation will result in a prefix-log, which can be used to predict remaining cycle-time from every observed event in the trace.
#
# Input for the **training_function** is a dictionary named **input_data**, which contain the following:
# - x_train
# - x_test
# - y_train
# - y_test
#
# Output is an **inference table** containing predictions and actual target values for the test data. This table is used for analysis of the results. The **eval_function** also uses this table to calculate aggregated metrics.

# %%
def training_function(input_data):
    print("training")
    
    """
    Example model: Lasso regression
    This is just an example of how to define your model in this framework.
    Using this model on this data format is not advised as we break i.i.d. assumptions.
    """

    #retrieve model class from sklearn
    from sklearn import linear_model


    # Lasso model
    #reg = linear_model.Lasso(alpha=0.1)
    # OLS
    reg = linear_model.LinearRegression()

    #reshape training data for this type of model 
    #(from: N x t x k, to: N x (t x k))
    #num_obs = input_data["x_train"].shape[0]
    from numpy import prod
    flattened_dim = prod(input_data["x_train"].shape[1:])

    #train the regression model
    reg.fit(input_data["x_train"].reshape((input_data["x_train"].shape[0], flattened_dim)), input_data["y_train"])

    #predict on the test data
    y_pred = reg.predict(input_data["x_test"].reshape((input_data["x_test"].shape[0], flattened_dim)))

    #get the inference table (used for analysis of the final results)
    inference = input_data["Inference_test"]
    
    #add predictions to the inference table
    inference["y_pred"] = y_pred
    return inference

#from sklearn.metrics 

def eval_function(inference):
    print("evaluation")
    """
    Example evaluation: Aggregated scores
    The inference table also enable the ability to make trace or prefix-level evaluations using its id variables
    """
    from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score

    y = inference["y"]
    y_pred = inference["y_pred"]

    MSE = mean_squared_error(y, y_pred)
    MAE = mean_absolute_error(y, y_pred)
    R2 = r2_score(y, y_pred)
    EVAR = explained_variance_score(y, y_pred)

    # the resulting metrics should be stored in a dictionary and be scalars only
    # adding prefixes to column name (key) is suggested when logging many metrics
    metrics = {"TEST_MSE":MSE,
              "TEST_MAE":MAE,
              "TEST_R2":R2,
              "TEST_EVAR":EVAR}
    print(metrics)
    return metrics

# %% [markdown]
# # Perform the experiments
# Now we perform the experiments using the defined training and evaluation functions.

# %%
from SynBPS.simulation.simulation_pipeline import run_experiments
results = run_experiments(training_function, 
                          eval_function, 
                          output_dir="",
                          out_file="results.csv", 
                          design_table="design_table.csv")
# Out:
# Run: 0
# traces: 500
# eventlog saved to: 0_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 08:30:43
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     b            1  2015-01-02 08:30:43 2015-01-02 21:11:53
# 1   1     e            2  2015-01-03 06:00:00 2015-01-03 14:09:16
# 2   1     f            3  2015-01-04 06:00:00 2015-01-05 14:14:09
# 3   1     c            4  2015-01-05 16:25:27 2015-01-05 16:53:06
# 4   1     d            5  2015-01-05 16:59:13 2015-01-05 22:45:09
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 08:30:43
# Last event starts at: 2017-01-11 16:12:28
# Train-test split happens at: 2016-01-07 08:30:43
# =======================================
# 500
# 500
# 1205
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 968
# Testset size (with prefixes of  5 ): 1032
# ==========================================
# X: observations, timesteps, vars
# (968, 5, 11)
# y_train: observations, labels
# (968, 1)
# y_t_train: observations, labels
# (968, 1)
# y_a_train: observations, labels
# (968, 4)
# Inference train: 968
# Inference test:  1032
# training
# evaluation
# {'TEST_MSE': np.float64(13737947686.240091), 'TEST_MAE': np.float64(86825.47453025468), 'TEST_R2': 0.4863736384798195, 'TEST_EVAR': 0.48781432513750356}
# Run: 1
# traces: 500
# eventlog saved to: 1_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-04 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     f            1  2015-01-04 06:00:00 2015-01-04 14:02:43
# 1   1     b            2  2015-01-04 16:42:52 2015-01-04 23:13:04
# 2   1     d            3  2015-01-05 06:00:00 2015-01-05 10:10:17
# 3   1     e            4  2015-01-06 06:00:00 2015-01-06 11:52:33
# 4   1     c            5  2015-01-06 13:55:48 2015-01-07 04:35:44
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-04 06:00:00
# Last event starts at: 2016-12-27 06:00:00
# Train-test split happens at: 2016-01-01 06:00:00
# =======================================
# 500
# 500
# 1262
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1012
# Testset size (with prefixes of  5 ): 988
# ==========================================
# X: observations, timesteps, vars
# (1012, 5, 11)
# y_train: observations, labels
# (1012, 1)
# y_t_train: observations, labels
# (1012, 1)
# y_a_train: observations, labels
# (1012, 4)
# Inference train: 1012
# Inference test:  988
# training
# evaluation
# {'TEST_MSE': np.float64(12959919306.594921), 'TEST_MAE': np.float64(87515.7583315101), 'TEST_R2': 0.40000583421357794, 'TEST_EVAR': 0.4076825628252637}
# Run: 2
# traces: 500
# eventlog saved to: 2_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 09:15:22
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     d            1  2015-01-02 09:15:22 2015-01-02 19:56:00
# 1   1     c            2  2015-01-03 06:00:00 2015-01-03 06:20:12
# 2   1     e            3  2015-01-03 10:23:06 2015-01-03 14:36:13
# 3   1     b            4  2015-01-03 17:57:00 2015-01-03 22:05:57
# 4   1     f            5  2015-01-04 06:00:00 2015-01-04 06:17:06
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 09:15:22
# Last event starts at: 2017-01-04 06:00:00
# Train-test split happens at: 2016-01-03 09:15:22
# =======================================
# 500
# 500
# 1210
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 972
# Testset size (with prefixes of  5 ): 1028
# ==========================================
# X: observations, timesteps, vars
# (972, 5, 11)
# y_train: observations, labels
# (972, 1)
# y_t_train: observations, labels
# (972, 1)
# y_a_train: observations, labels
# (972, 4)
# Inference train: 972
# Inference test:  1028
# training
# evaluation
# {'TEST_MSE': np.float64(11450036865.877337), 'TEST_MAE': np.float64(77766.17313189451), 'TEST_R2': 0.2824811428767884, 'TEST_EVAR': 0.28935349636694596}
# Run: 3
# traces: 500
# eventlog saved to: 3_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-03 15:26:16
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     b            1  2015-01-03 15:26:16 2015-01-04 10:16:20
# 1   1     c            2  2015-01-04 14:36:23 2015-01-04 21:22:47
# 2   1     f            3  2015-01-05 07:43:47 2015-01-06 02:22:08
# 3   1     e            4  2015-01-06 06:00:00 2015-01-06 11:04:32
# 4   1     d            5  2015-01-06 12:17:22 2015-01-06 13:49:23
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-03 15:26:16
# Last event starts at: 2017-01-04 17:04:32
# Train-test split happens at: 2016-01-04 15:26:16
# =======================================
# 500
# 500
# 1263
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1016
# Testset size (with prefixes of  5 ): 984
# ==========================================
# X: observations, timesteps, vars
# (1016, 5, 11)
# y_train: observations, labels
# (1016, 1)
# y_t_train: observations, labels
# (1016, 1)
# y_a_train: observations, labels
# (1016, 4)
# Inference train: 1016
# Inference test:  984
# training
# evaluation
# {'TEST_MSE': np.float64(17231226078.837418), 'TEST_MAE': np.float64(101097.21432128476), 'TEST_R2': 0.2748721170843862, 'TEST_EVAR': 0.2800571236029089}
# Run: 4
# traces: 500
# eventlog saved to: 4_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 09:13:22
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     d            1  2015-01-02 09:13:22 2015-01-02 11:42:56
# 1   1     c            2  2015-01-02 13:10:28 2015-01-03 17:47:47
# 2   1     f            3  2015-01-04 06:00:00 2015-01-04 09:38:39
# 3   1     e            4  2015-01-04 14:14:41 2015-01-04 20:23:16
# 4   1     b            5  2015-01-05 06:00:00 2015-01-05 10:31:49
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 09:13:22
# Last event starts at: 2017-02-25 06:00:00
# Train-test split happens at: 2016-01-29 09:13:22
# =======================================
# 500
# 500
# 1305
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1048
# Testset size (with prefixes of  5 ): 952
# ==========================================
# X: observations, timesteps, vars
# (1048, 5, 11)
# y_train: observations, labels
# (1048, 1)
# y_t_train: observations, labels
# (1048, 1)
# y_a_train: observations, labels
# (1048, 4)
# Inference train: 1048
# Inference test:  952
# training
# evaluation
# {'TEST_MSE': np.float64(19700626642.336468), 'TEST_MAE': np.float64(102556.59291823572), 'TEST_R2': 0.36432174511083315, 'TEST_EVAR': 0.36679350305266767}
# Run: 5
# traces: 500
# eventlog saved to: 5_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-05 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     f            1  2015-01-05 06:00:00 2015-01-05 08:21:59
# 1   1     b            2  2015-01-06 06:00:00 2015-01-06 15:00:01
# 2   1     d            3  2015-01-06 17:04:28 2015-01-06 21:15:49
# 3   1     c            4  2015-01-09 06:00:00 2015-01-09 08:10:02
# 4   1     e            5  2015-01-09 13:09:04 2015-01-10 02:06:15
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-05 06:00:00
# Last event starts at: 2017-01-21 13:06:29
# Train-test split happens at: 2016-01-14 06:00:00
# =======================================
# 500
# 500
# 1275
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1024
# Testset size (with prefixes of  5 ): 976
# ==========================================
# X: observations, timesteps, vars
# (1024, 5, 11)
# y_train: observations, labels
# (1024, 1)
# y_t_train: observations, labels
# (1024, 1)
# y_a_train: observations, labels
# (1024, 4)
# Inference train: 1024
# Inference test:  976
# training
# evaluation
# {'TEST_MSE': np.float64(11903884830.579302), 'TEST_MAE': np.float64(79701.09665864804), 'TEST_R2': 0.5535810937335008, 'TEST_EVAR': 0.5568091497119005}
# Run: 6
# traces: 500
# eventlog saved to: 6_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     e            1  2015-01-02 06:00:00 2015-01-02 11:29:56
# 1   1     d            2  2015-01-02 16:32:46 2015-01-02 19:57:23
# 2   1     f            3  2015-01-03 06:00:00 2015-01-03 08:58:39
# 3   1     b            4  2015-01-03 10:58:14 2015-01-04 06:53:00
# 4   1     c            5  2015-01-04 13:15:42 2015-01-04 23:01:28
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 06:00:00
# Last event starts at: 2017-01-28 07:34:34
# Train-test split happens at: 2016-01-16 06:00:00
# =======================================
# 500
# 500
# 1225
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 984
# Testset size (with prefixes of  5 ): 1016
# ==========================================
# X: observations, timesteps, vars
# (984, 5, 11)
# y_train: observations, labels
# (984, 1)
# y_t_train: observations, labels
# (984, 1)
# y_a_train: observations, labels
# (984, 4)
# Inference train: 984
# Inference test:  1016
# training
# evaluation
# {'TEST_MSE': np.float64(11336299689.880749), 'TEST_MAE': np.float64(84776.43480738928), 'TEST_R2': 0.48633038411680174, 'TEST_EVAR': 0.48789706213784423}
# Run: 7
# traces: 500
# eventlog saved to: 7_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-04 14:11:16
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     b            1  2015-01-04 14:11:16 2015-01-05 01:27:40
# 1   1     f            2  2015-01-05 06:00:00 2015-01-05 07:02:58
# 2   1     e            3  2015-01-05 08:05:43 2015-01-06 03:08:17
# 3   1     d            4  2015-01-06 06:04:21 2015-01-06 22:08:45
# 4   1     c            5  2015-01-09 06:00:00 2015-01-09 13:04:44
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-04 14:11:16
# Last event starts at: 2017-01-30 05:59:59
# Train-test split happens at: 2016-01-17 14:11:16
# =======================================
# 500
# 500
# 1294
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1044
# Testset size (with prefixes of  5 ): 956
# ==========================================
# X: observations, timesteps, vars
# (1044, 5, 11)
# y_train: observations, labels
# (1044, 1)
# y_t_train: observations, labels
# (1044, 1)
# y_a_train: observations, labels
# (1044, 4)
# Inference train: 1044
# Inference test:  956
# training
# evaluation
# {'TEST_MSE': np.float64(17381657273.269615), 'TEST_MAE': np.float64(103763.7057428946), 'TEST_R2': 0.3140328930889559, 'TEST_EVAR': 0.31429205579698705}
# Run: 8
# traces: 500
# eventlog saved to: 8_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-03 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     c            1  2015-01-03 06:00:00 2015-01-04 05:16:43
# 1   1     e            2  2015-01-04 11:27:45 2015-01-04 11:46:25
# 2   1     b            3  2015-01-04 15:28:19 2015-01-04 16:01:54
# 3   1     f            4  2015-01-05 06:00:00 2015-01-05 07:57:40
# 4   1     d            5  2015-01-06 06:00:00 2015-01-06 18:24:01
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-03 06:00:00
# Last event starts at: 2017-01-04 06:00:00
# Train-test split happens at: 2016-01-04 06:00:00
# =======================================
# 500
# 500
# 1315
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1052
# Testset size (with prefixes of  5 ): 948
# ==========================================
# X: observations, timesteps, vars
# (1052, 5, 11)
# y_train: observations, labels
# (1052, 1)
# y_t_train: observations, labels
# (1052, 1)
# y_a_train: observations, labels
# (1052, 4)
# Inference train: 1052
# Inference test:  948
# training
# evaluation
# {'TEST_MSE': np.float64(8469993994.119936), 'TEST_MAE': np.float64(69465.70410923414), 'TEST_R2': 0.45835043131673137, 'TEST_EVAR': 0.4597837653025797}
# Run: 9
# traces: 500
# eventlog saved to: 9_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 16:26:15
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     e            1  2015-01-02 16:26:15 2015-01-02 18:21:40
# 1   1     f            2  2015-01-03 06:00:00 2015-01-04 07:36:51
# 2   1     b            3  2015-01-04 11:05:49 2015-01-04 18:17:19
# 3   1     d            4  2015-01-05 06:00:00 2015-01-05 11:13:58
# 4   1     c            5  2015-01-05 14:13:36 2015-01-06 01:42:59
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 16:26:15
# Last event starts at: 2017-02-25 15:22:11
# Train-test split happens at: 2016-01-29 16:26:15
# =======================================
# 500
# 500
# 1252
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1008
# Testset size (with prefixes of  5 ): 992
# ==========================================
# X: observations, timesteps, vars
# (1008, 5, 11)
# y_train: observations, labels
# (1008, 1)
# y_t_train: observations, labels
# (1008, 1)
# y_a_train: observations, labels
# (1008, 4)
# Inference train: 1008
# Inference test:  992
# training
# evaluation
# {'TEST_MSE': np.float64(12900683315.372274), 'TEST_MAE': np.float64(84669.1029826655), 'TEST_R2': 0.5290163426668791, 'TEST_EVAR': 0.5293009432560967}
# Run: 10
# traces: 500
# eventlog saved to: 10_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 15:48:34
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     b            1  2015-01-02 15:48:34 2015-01-02 23:03:26
# 1   1     c            2  2015-01-03 06:00:00 2015-01-03 21:37:58
# 2   1     e            3  2015-01-04 06:00:00 2015-01-04 07:56:54
# 3   1     d            4  2015-01-04 14:06:08 2015-01-04 21:46:34
# 4   1     f            5  2015-01-05 06:00:00 2015-01-06 18:49:02
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 15:48:34
# Last event starts at: 2017-01-24 06:00:00
# Train-test split happens at: 2016-01-13 15:48:34
# =======================================
# 500
# 500
# 1219
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 984
# Testset size (with prefixes of  5 ): 1016
# ==========================================
# X: observations, timesteps, vars
# (984, 5, 11)
# y_train: observations, labels
# (984, 1)
# y_t_train: observations, labels
# (984, 1)
# y_a_train: observations, labels
# (984, 4)
# Inference train: 984
# Inference test:  1016
# training
# evaluation
# {'TEST_MSE': np.float64(18858704199.64127), 'TEST_MAE': np.float64(105503.82847599538), 'TEST_R2': 0.5238243667573924, 'TEST_EVAR': 0.5249108964462896}
# Run: 11
# traces: 500
# eventlog saved to: 11_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-04 11:42:28
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     c            1  2015-01-04 11:42:28 2015-01-07 19:37:51
# 1   1     b            2  2015-01-09 06:00:00 2015-01-10 03:29:05
# 2   1     d            3  2015-01-10 13:16:21 2015-01-12 09:48:26
# 3   1     e            4  2015-01-13 06:00:00 2015-01-14 01:51:26
# 4   1     f            5  2015-01-16 06:00:00 2015-01-16 09:00:35
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-04 11:42:28
# Last event starts at: 2016-12-07 08:47:03
# Train-test split happens at: 2015-12-22 11:42:28
# =======================================
# 500
# 500
# 1266
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1020
# Testset size (with prefixes of  5 ): 980
# ==========================================
# X: observations, timesteps, vars
# (1020, 5, 11)
# y_train: observations, labels
# (1020, 1)
# y_t_train: observations, labels
# (1020, 1)
# y_a_train: observations, labels
# (1020, 4)
# Inference train: 1020
# Inference test:  980
# training
# evaluation
# {'TEST_MSE': np.float64(18728594829.940754), 'TEST_MAE': np.float64(109158.4554511086), 'TEST_R2': 0.3819406968649177, 'TEST_EVAR': 0.3831991751766797}
# Run: 12
# traces: 500
# eventlog saved to: 12_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     c            1  2015-01-02 06:00:00 2015-01-02 06:02:36
# 1   1     f            2  2015-01-02 11:27:43 2015-01-02 15:11:26
# 2   1     d            3  2015-01-03 06:00:00 2015-01-03 07:51:12
# 3   1     b            4  2015-01-03 12:45:48 2015-01-03 15:24:35
# 4   1     e            5  2015-01-04 06:00:00 2015-01-04 10:08:01
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 06:00:00
# Last event starts at: 2017-03-04 14:26:43
# Train-test split happens at: 2016-02-02 06:00:00
# =======================================
# 500
# 500
# 1273
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1024
# Testset size (with prefixes of  5 ): 976
# ==========================================
# X: observations, timesteps, vars
# (1024, 5, 11)
# y_train: observations, labels
# (1024, 1)
# y_t_train: observations, labels
# (1024, 1)
# y_a_train: observations, labels
# (1024, 4)
# Inference train: 1024
# Inference test:  976
# training
# evaluation
# {'TEST_MSE': np.float64(3.3693346569795932e+16), 'TEST_MAE': np.float64(8328841.124309372), 'TEST_R2': -3392998.119915491, 'TEST_EVAR': -3392920.4730974715}
# Run: 13
# traces: 500
# eventlog saved to: 13_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-03 07:01:02
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     c            1  2015-01-03 07:01:02 2015-01-03 09:26:58
# 1   1     d            2  2015-01-03 14:03:40 2015-01-04 01:46:36
# 2   1     b            3  2015-01-04 06:00:00 2015-01-04 10:57:32
# 3   1     e            4  2015-01-04 14:32:02 2015-01-04 17:07:25
# 4   1     f            5  2015-01-05 06:00:00 2015-01-05 20:35:20
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-03 07:01:02
# Last event starts at: 2017-02-19 06:00:00
# Train-test split happens at: 2016-01-27 07:01:02
# =======================================
# 500
# 500
# 1239
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 992
# Testset size (with prefixes of  5 ): 1008
# ==========================================
# X: observations, timesteps, vars
# (992, 5, 11)
# y_train: observations, labels
# (992, 1)
# y_t_train: observations, labels
# (992, 1)
# y_a_train: observations, labels
# (992, 4)
# Inference train: 992
# Inference test:  1008
# training
# evaluation
# {'TEST_MSE': np.float64(9044577520.297081), 'TEST_MAE': np.float64(75599.64862783301), 'TEST_R2': 0.3883575495330366, 'TEST_EVAR': 0.3896718037888509}
# Run: 14
# traces: 500
# eventlog saved to: 14_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-05 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     b            1  2015-01-05 06:00:00 2015-01-05 12:00:31
# 1   1     f            2  2015-01-05 17:09:22 2015-01-06 21:37:48
# 2   1     d            3  2015-01-09 06:00:00 2015-01-09 14:38:26
# 3   1     c            4  2015-01-10 06:00:00 2015-01-10 07:16:41
# 4   1     e            5  2015-01-10 07:49:39 2015-01-10 08:15:05
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-05 06:00:00
# Last event starts at: 2017-03-13 06:00:00
# Train-test split happens at: 2016-02-09 06:00:00
# =======================================
# 500
# 500
# 1316
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5', 'y_a_t1_6']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1056
# Testset size (with prefixes of  5 ): 944
# ==========================================
# X: observations, timesteps, vars
# (1056, 5, 11)
# y_train: observations, labels
# (1056, 1)
# y_t_train: observations, labels
# (1056, 1)
# y_a_train: observations, labels
# (1056, 5)
# Inference train: 1056
# Inference test:  944
# training
# evaluation
# {'TEST_MSE': np.float64(120869554728657.72), 'TEST_MAE': np.float64(792890.4478710913), 'TEST_R2': -3817.8975314482113, 'TEST_EVAR': -3817.89749469818}
# Run: 15
# traces: 500
# eventlog saved to: 15_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     c            1  2015-01-02 06:00:00 2015-01-03 02:19:49
# 1   1     f            2  2015-01-03 06:00:00 2015-01-03 09:07:59
# 2   1     d            3  2015-01-03 13:35:02 2015-01-04 04:22:00
# 3   1     b            4  2015-01-04 06:25:44 2015-01-04 07:18:17
# 4   1     e            5  2015-01-04 09:04:34 2015-01-04 12:22:49
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 06:00:00
# Last event starts at: 2017-02-18 06:00:00
# Train-test split happens at: 2016-01-27 06:00:00
# =======================================
# 500
# 500
# 1225
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 980
# Testset size (with prefixes of  5 ): 1020
# ==========================================
# X: observations, timesteps, vars
# (980, 5, 11)
# y_train: observations, labels
# (980, 1)
# y_t_train: observations, labels
# (980, 1)
# y_a_train: observations, labels
# (980, 4)
# Inference train: 980
# Inference test:  1020
# training
# evaluation
# {'TEST_MSE': np.float64(12227797697.175482), 'TEST_MAE': np.float64(86761.01730629416), 'TEST_R2': 0.38304953154272436, 'TEST_EVAR': 0.39141915399944227}
# Run: 16
# traces: 500
# eventlog saved to: 16_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 07:38:57
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     b            1  2015-01-02 07:38:57 2015-01-03 02:23:10
# 1   1     d            2  2015-01-03 08:33:07 2015-01-03 09:13:41
# 2   1     c            3  2015-01-03 10:38:23 2015-01-05 22:37:51
# 3   1     f            4  2015-01-06 06:00:00 2015-01-06 08:25:29
# 4   1     e            5  2015-01-06 09:29:11 2015-01-08 14:46:51
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 07:38:57
# Last event starts at: 2016-12-20 14:29:33
# Train-test split happens at: 2015-12-28 07:38:57
# =======================================
# 500
# 500
# 1328
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1068
# Testset size (with prefixes of  5 ): 932
# ==========================================
# X: observations, timesteps, vars
# (1068, 5, 11)
# y_train: observations, labels
# (1068, 1)
# y_t_train: observations, labels
# (1068, 1)
# y_a_train: observations, labels
# (1068, 4)
# Inference train: 1068
# Inference test:  932
# training
# evaluation
# {'TEST_MSE': np.float64(17144600602.457249), 'TEST_MAE': np.float64(102403.81665609262), 'TEST_R2': 0.4499481777633437, 'TEST_EVAR': 0.4526881953238566}
# Run: 17
# traces: 500
# eventlog saved to: 17_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-04 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     e            1  2015-01-04 06:00:00 2015-01-04 06:12:46
# 1   1     d            2  2015-01-04 09:46:03 2015-01-04 13:12:51
# 2   1     b            3  2015-01-05 06:00:00 2015-01-05 11:19:48
# 3   1     c            4  2015-01-05 15:25:57 2015-01-05 21:28:55
# 4   1     f            5  2015-01-06 06:00:00 2015-01-06 07:33:13
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-04 06:00:00
# Last event starts at: 2016-12-31 06:00:00
# Train-test split happens at: 2016-01-03 06:00:00
# =======================================
# 500
# 500
# 1216
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 976
# Testset size (with prefixes of  5 ): 1024
# ==========================================
# X: observations, timesteps, vars
# (976, 5, 11)
# y_train: observations, labels
# (976, 1)
# y_t_train: observations, labels
# (976, 1)
# y_a_train: observations, labels
# (976, 4)
# Inference train: 976
# Inference test:  1024
# training
# evaluation
# {'TEST_MSE': np.float64(8531216492.226673), 'TEST_MAE': np.float64(71165.42186587676), 'TEST_R2': 0.4919591748991681, 'TEST_EVAR': 0.49609700176305427}
# Run: 18
# traces: 500
# eventlog saved to: 18_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 08:19:59
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     d            1  2015-01-02 08:19:59 2015-01-02 08:46:26
# 1   1     c            2  2015-01-02 15:04:46 2015-01-03 06:07:18
# 2   1     b            3  2015-01-03 11:47:34 2015-01-03 20:55:05
# 3   1     e            4  2015-01-04 15:59:59 2015-01-05 13:57:29
# 4   1     f            5  2015-01-06 06:00:00 2015-01-06 13:08:13
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 08:19:59
# Last event starts at: 2017-04-10 06:00:00
# Train-test split happens at: 2016-02-20 08:19:59
# =======================================
# 500
# 500
# 1225
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 984
# Testset size (with prefixes of  5 ): 1016
# ==========================================
# X: observations, timesteps, vars
# (984, 5, 11)
# y_train: observations, labels
# (984, 1)
# y_t_train: observations, labels
# (984, 1)
# y_a_train: observations, labels
# (984, 4)
# Inference train: 984
# Inference test:  1016
# training
# evaluation
# {'TEST_MSE': np.float64(50930691058556.305), 'TEST_MAE': np.float64(565800.735265331), 'TEST_R2': -1701.91990307289, 'TEST_EVAR': -1701.7818051645545}
# Run: 19
# traces: 500
# eventlog saved to: 19_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-04 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     d            1  2015-01-04 06:00:00 2015-01-04 11:28:53
# 1   1     c            2  2015-01-04 16:48:07 2015-01-04 17:06:56
# 2   1     e            3  2015-01-05 06:00:00 2015-01-06 07:23:56
# 3   1     b            4  2015-01-06 09:49:56 2015-01-06 11:19:19
# 4   1     f            5  2015-01-06 12:19:41 2015-01-06 16:47:25
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-03 15:39:15
# Last event starts at: 2017-01-24 06:00:00
# Train-test split happens at: 2016-01-14 15:39:15
# =======================================
# 500
# 500
# 1292
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1036
# Testset size (with prefixes of  5 ): 964
# ==========================================
# X: observations, timesteps, vars
# (1036, 5, 11)
# y_train: observations, labels
# (1036, 1)
# y_t_train: observations, labels
# (1036, 1)
# y_a_train: observations, labels
# (1036, 4)
# Inference train: 1036
# Inference test:  964
# training
# evaluation
# {'TEST_MSE': np.float64(12661437266.162601), 'TEST_MAE': np.float64(83485.9539837308), 'TEST_R2': 0.3863669231989274, 'TEST_EVAR': 0.38643526672746964}
# Run: 20
# traces: 500
# eventlog saved to: 20_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-04 07:00:51
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     b            1  2015-01-04 07:00:51 2015-01-05 02:37:25
# 1   1     e            2  2015-01-05 06:00:00 2015-01-05 11:07:09
# 2   1     c            3  2015-01-05 12:06:51 2015-01-05 13:26:37
# 3   1     f            4  2015-01-06 06:00:00 2015-01-06 14:46:28
# 4   1     d            5  2015-01-09 06:00:00 2015-01-10 12:32:00
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-04 07:00:51
# Last event starts at: 2017-01-30 17:05:37
# Train-test split happens at: 2016-01-18 07:00:51
# =======================================
# 500
# 500
# 1244
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1000
# Testset size (with prefixes of  5 ): 1000
# ==========================================
# X: observations, timesteps, vars
# (1000, 5, 11)
# y_train: observations, labels
# (1000, 1)
# y_t_train: observations, labels
# (1000, 1)
# y_a_train: observations, labels
# (1000, 4)
# Inference train: 1000
# Inference test:  1000
# training
# evaluation
# {'TEST_MSE': np.float64(12974185727.808844), 'TEST_MAE': np.float64(85053.83128447151), 'TEST_R2': 0.5404815993891137, 'TEST_EVAR': 0.548307233803901}
# Run: 21
# traces: 500
# eventlog saved to: 21_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-03 14:38:50
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     d            1  2015-01-03 14:38:50 2015-01-04 10:51:34
# 1   1     b            2  2015-01-04 13:20:59 2015-01-05 06:05:10
# 2   1     e            3  2015-01-05 06:42:04 2015-01-05 13:57:04
# 3   1     f            4  2015-01-06 06:00:00 2015-01-06 08:07:27
# 4   1     c            5  2015-01-06 11:19:21 2015-01-07 10:49:14
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-03 14:38:50
# Last event starts at: 2016-10-30 17:49:41
# Train-test split happens at: 2015-12-03 14:38:50
# =======================================
# 500
# 500
# 1275
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1024
# Testset size (with prefixes of  5 ): 976
# ==========================================
# X: observations, timesteps, vars
# (1024, 5, 11)
# y_train: observations, labels
# (1024, 1)
# y_t_train: observations, labels
# (1024, 1)
# y_a_train: observations, labels
# (1024, 4)
# Inference train: 1024
# Inference test:  976
# training
# evaluation
# {'TEST_MSE': np.float64(15258839244.509565), 'TEST_MAE': np.float64(96417.8007318359), 'TEST_R2': 0.4376823324936402, 'TEST_EVAR': 0.4462952637904677}
# Run: 22
# traces: 500
# eventlog saved to: 22_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-03 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     b            1  2015-01-03 06:00:00 2015-01-05 02:54:39
# 1   1     d            2  2015-01-05 06:39:18 2015-01-09 04:28:33
# 2   1     c            3  2015-01-09 07:00:21 2015-01-09 11:08:53
# 3   1     e            4  2015-01-09 14:14:10 2015-01-10 06:01:47
# 4   1     f            5  2015-01-10 08:06:44 2015-01-10 15:41:45
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-03 06:00:00
# Last event starts at: 2017-01-22 17:54:11
# Train-test split happens at: 2016-01-14 06:00:00
# =======================================
# 500
# 500
# 1235
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 988
# Testset size (with prefixes of  5 ): 1012
# ==========================================
# X: observations, timesteps, vars
# (988, 5, 11)
# y_train: observations, labels
# (988, 1)
# y_t_train: observations, labels
# (988, 1)
# y_a_train: observations, labels
# (988, 4)
# Inference train: 988
# Inference test:  1012
# training
# evaluation
# {'TEST_MSE': np.float64(10344270522.821255), 'TEST_MAE': np.float64(78155.0965807339), 'TEST_R2': 0.5272731899538562, 'TEST_EVAR': 0.5409079468921023}
# Run: 23
# traces: 500
# eventlog saved to: 23_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-04 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     c            1  2015-01-04 06:00:00 2015-01-04 10:06:52
# 1   1     d            2  2015-01-04 13:09:09 2015-01-04 14:53:52
# 2   1     e            3  2015-01-04 16:47:23 2015-01-04 20:18:28
# 3   1     b            4  2015-01-05 06:00:00 2015-01-05 14:07:23
# 4   1     f            5  2015-01-06 06:00:00 2015-01-07 03:42:27
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-04 06:00:00
# Last event starts at: 2016-11-13 17:25:30
# Train-test split happens at: 2015-12-10 06:00:00
# =======================================
# 500
# 500
# 1252
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1004
# Testset size (with prefixes of  5 ): 996
# ==========================================
# X: observations, timesteps, vars
# (1004, 5, 11)
# y_train: observations, labels
# (1004, 1)
# y_t_train: observations, labels
# (1004, 1)
# y_a_train: observations, labels
# (1004, 4)
# Inference train: 1004
# Inference test:  996
# training
# evaluation
# {'TEST_MSE': np.float64(13142332728.764347), 'TEST_MAE': np.float64(88071.47998277322), 'TEST_R2': 0.34915409533212327, 'TEST_EVAR': 0.3495376029513909}
# Run: 24
# traces: 500
# eventlog saved to: 24_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 17:15:58
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     c            1  2015-01-02 17:15:58 2015-01-03 02:19:45
# 1   1     d            2  2015-01-03 06:30:58 2015-01-03 15:13:13
# 2   1     e            3  2015-01-04 06:00:00 2015-01-04 08:24:01
# 3   1     f            4  2015-01-04 12:03:11 2015-01-04 12:35:50
# 4   1     b            5  2015-01-05 06:00:00 2015-01-05 15:52:59
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 17:15:58
# Last event starts at: 2017-03-10 12:11:05
# Train-test split happens at: 2016-02-05 17:15:58
# =======================================
# 500
# 500
# 1240
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 996
# Testset size (with prefixes of  5 ): 1004
# ==========================================
# X: observations, timesteps, vars
# (996, 5, 11)
# y_train: observations, labels
# (996, 1)
# y_t_train: observations, labels
# (996, 1)
# y_a_train: observations, labels
# (996, 4)
# Inference train: 996
# Inference test:  1004
# training
# evaluation
# {'TEST_MSE': np.float64(303689250241487.25), 'TEST_MAE': np.float64(1184051.2073438026), 'TEST_R2': -16063.16506179606, 'TEST_EVAR': -16058.922865515886}

# %% [markdown]
# # Analysis
# Work in progress..

# %%
import pandas as pd
df = pd.read_csv("results.csv")
df
# Out:
#    process_entropy  number_of_traces  statespace_size process_type  \
# 0      min_entropy             500.0                5   memoryless
# 1      min_entropy             500.0                5   memoryless
# 2      min_entropy             500.0                5   memoryless
# 3      min_entropy             500.0                5   memoryless
# 4      min_entropy             500.0                5   memoryless
# 5      min_entropy             500.0                5   memoryless
# 6      min_entropy             500.0                5   memoryless
# 7      min_entropy             500.0                5   memoryless
# 8      min_entropy             500.0                5   memoryless
# 9      min_entropy             500.0                5   memoryless
# 10     min_entropy             500.0                5   memoryless
# 11     min_entropy             500.0                5   memoryless
# 12     min_entropy             500.0                5   memoryless
# 13     min_entropy             500.0                5   memoryless
# 14     min_entropy             500.0                5   memoryless
# 15     min_entropy             500.0                5   memoryless
# 16     min_entropy             500.0                5   memoryless
# 17     min_entropy             500.0                5   memoryless
# 18     min_entropy             500.0                5   memoryless
# 19     min_entropy             500.0                5   memoryless
# 20     min_entropy             500.0                5   memoryless
# 21     min_entropy             500.0                5   memoryless
# 22     min_entropy             500.0                5   memoryless
# 23     min_entropy             500.0                5   memoryless
# 24     min_entropy             500.0                5   memoryless
#
#     process_memory  med_ent_n_transitions  inter_arrival_time  \
# 0              2.0                    1.0                 1.5
# 1              2.0                    2.0                 1.5
# 2              2.0                    3.0                 1.5
# 3              2.0                    4.0                 1.5
# 4              2.0                    5.0                 1.5
# 5              2.0                    1.0                 1.5
# 6              2.0                    2.0                 1.5
# 7              2.0                    3.0                 1.5
# 8              2.0                    4.0                 1.5
# 9              2.0                    5.0                 1.5
# 10             2.0                    1.0                 1.5
# 11             2.0                    2.0                 1.5
# 12             2.0                    3.0                 1.5
# 13             2.0                    4.0                 1.5
# 14             2.0                    5.0                 1.5
# 15             2.0                    1.0                 1.5
# 16             2.0                    2.0                 1.5
# 17             2.0                    3.0                 1.5
# 18             2.0                    4.0                 1.5
# 19             2.0                    5.0                 1.5
# 20             2.0                    1.0                 1.5
# 21             2.0                    2.0                 1.5
# 22             2.0                    3.0                 1.5
# 23             2.0                    4.0                 1.5
# 24             2.0                    5.0                 1.5
#
#     process_stability_scale  resource_availability_p  resource_availability_n  \
# 0                       0.1                      0.5                      3.0
# 1                       0.1                      0.5                      3.0
# 2                       0.1                      0.5                      3.0
# 3                       0.1                      0.5                      3.0
# 4                       0.1                      0.5                      3.0
# 5                       0.1                      0.5                      3.0
# 6                       0.1                      0.5                      3.0
# 7                       0.1                      0.5                      3.0
# 8                       0.1                      0.5                      3.0
# 9                       0.1                      0.5                      3.0
# 10                      0.1                      0.5                      3.0
# 11                      0.1                      0.5                      3.0
# 12                      0.1                      0.5                      3.0
# 13                      0.1                      0.5                      3.0
# 14                      0.1                      0.5                      3.0
# 15                      0.1                      0.5                      3.0
# 16                      0.1                      0.5                      3.0
# 17                      0.1                      0.5                      3.0
# 18                      0.1                      0.5                      3.0
# 19                      0.1                      0.5                      3.0
# 20                      0.1                      0.5                      3.0
# 21                      0.1                      0.5                      3.0
# 22                      0.1                      0.5                      3.0
# 23                      0.1                      0.5                      3.0
# 24                      0.1                      0.5                      3.0
#
#     ...  num_events  num_variants avg_tracelen  min_tracelen  max_tracelen  \
# 0   ...        2500             1          5.0             5             5
# 1   ...        2500             1          5.0             5             5
# 2   ...        2500             1          5.0             5             5
# 3   ...        2500             1          5.0             5             5
# 4   ...        2500             1          5.0             5             5
# 5   ...        2500             1          5.0             5             5
# 6   ...        2500             1          5.0             5             5
# 7   ...        2500             1          5.0             5             5
# 8   ...        2500             1          5.0             5             5
# 9   ...        2500             1          5.0             5             5
# 10  ...        2500             1          5.0             5             5
# 11  ...        2500             1          5.0             5             5
# 12  ...        2500             1          5.0             5             5
# 13  ...        2500             1          5.0             5             5
# 14  ...        2500             1          5.0             5             5
# 15  ...        2500             1          5.0             5             5
# 16  ...        2500             1          5.0             5             5
# 17  ...        2500             1          5.0             5             5
# 18  ...        2500             1          5.0             5             5
# 19  ...        2500             1          5.0             5             5
# 20  ...        2500             1          5.0             5             5
# 21  ...        2500             1          5.0             5             5
# 22  ...        2500             1          5.0             5             5
# 23  ...        2500             1          5.0             5             5
# 24  ...        2500             1          5.0             5             5
#
#     RESULT_num_events      TEST_MSE      TEST_MAE       TEST_R2     TEST_EVAR
# 0                2500  1.373795e+10  8.682547e+04  4.863736e-01  4.878143e-01
# 1                2500  1.295992e+10  8.751576e+04  4.000058e-01  4.076826e-01
# 2                2500  1.145004e+10  7.776617e+04  2.824811e-01  2.893535e-01
# 3                2500  1.723123e+10  1.010972e+05  2.748721e-01  2.800571e-01
# 4                2500  1.970063e+10  1.025566e+05  3.643217e-01  3.667935e-01
# 5                2500  1.190388e+10  7.970110e+04  5.535811e-01  5.568091e-01
# 6                2500  1.133630e+10  8.477643e+04  4.863304e-01  4.878971e-01
# 7                2500  1.738166e+10  1.037637e+05  3.140329e-01  3.142921e-01
# 8                2500  8.469994e+09  6.946570e+04  4.583504e-01  4.597838e-01
# 9                2500  1.290068e+10  8.466910e+04  5.290163e-01  5.293009e-01
# 10               2500  1.885870e+10  1.055038e+05  5.238244e-01  5.249109e-01
# 11               2500  1.872859e+10  1.091585e+05  3.819407e-01  3.831992e-01
# 12               2500  3.369335e+16  8.328841e+06 -3.392998e+06 -3.392920e+06
# 13               2500  9.044578e+09  7.559965e+04  3.883575e-01  3.896718e-01
# 14               2500  1.208696e+14  7.928904e+05 -3.817898e+03 -3.817897e+03
# 15               2500  1.222780e+10  8.676102e+04  3.830495e-01  3.914192e-01
# 16               2500  1.714460e+10  1.024038e+05  4.499482e-01  4.526882e-01
# 17               2500  8.531216e+09  7.116542e+04  4.919592e-01  4.960970e-01
# 18               2500  5.093069e+13  5.658007e+05 -1.701920e+03 -1.701782e+03
# 19               2500  1.266144e+10  8.348595e+04  3.863669e-01  3.864353e-01
# 20               2500  1.297419e+10  8.505383e+04  5.404816e-01  5.483072e-01
# 21               2500  1.525884e+10  9.641780e+04  4.376823e-01  4.462953e-01
# 22               2500  1.034427e+10  7.815510e+04  5.272732e-01  5.409079e-01
# 23               2500  1.314233e+10  8.807148e+04  3.491541e-01  3.495376e-01
# 24               2500  3.036893e+14  1.184051e+06 -1.606317e+04 -1.605892e+04
#
# [25 rows x 33 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create boxplot
sns.boxplot(data=df, x='med_ent_n_transitions', y='TEST_R2')

# Calculate medians and plot lines
medians = df.groupby(['med_ent_n_transitions'])['TEST_R2'].median().values
n = len(medians)
sns.lineplot(x=range(n), y=medians, sort=False)

# Set title and y-axis range
plt.title('Boxplot with Median Lines')
plt.ylim(0, 1)

plt.show()
