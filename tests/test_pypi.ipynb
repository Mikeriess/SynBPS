# %%
# Suppress warnings in this notebook
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Make an experimental design table
# Here the settings for the experiments can be modified in the dictionary called run_settings. Refer to the paper for more details on of each of the parameters.

# %%
run_settings = {# level of entropy: min, medium and/or max
                "process_entropy":["min_entropy","med_entropy","max_entropy"],
                
                # number of traces/cases in the event-log
                "number_of_traces":[100],

                # number of activity types
                "statespace_size":[5,10], 

                # first or higher-order markov chain to represent the transitions
                "process_type":["memoryless","memory"], 
                
                # order of HOMC - only specify this when using process with memory
                "process_memory":[2,4],
                
                # number of transitions - only used for medium entropy (should be higher than 2 and < statespace size)
                "med_ent_n_transitions":[3, 5],
                                
                # lambda parameter of inter-arrival times
                "inter_arrival_time":[1.5],
                
                # lambda parameter of process noise
                "process_stability_scale":[0.1],
                
                # probability of agent being available
                "resource_availability_p":[0.5],

                # number of agents in the process
                "resource_availability_n":[3],

                # waiting time in full days, when no agent is available
                "resource_availability_m":[0.041],
                
                # variation between activity durations
                "activity_duration_lambda_range":[1, 5],
                
                # business hours definition: when can cases be processed? ()
                "Deterministic_offset_W":["weekdays", "all-week"],

                # time-unit for a full week: days = 7, hrs = 24*7, etc.
                "Deterministic_offset_u":[7],
                
                # training data format (See Verenich et al., 2019): 
                # True - use first event to predict total cycle-time. 
                # False - use Prefix-log format / each event to predict remaining cycle time.
                "first_state_model":[True],

                # offset for the timestamps used (1970 time after 1970)
                "datetime_offset":[35],
                
                # number of repetitions of the experiments: duplicates the experiment table (2 times here)
                "num_replications":list(range(0, 2))
               }


# import the make_design_table function to generate a full factorial experimental design table
from SynBPS.simulation.DoE import make_design_table
df = make_design_table(run_settings, file="data/design_table.csv")

# inspect the resulting design table
df
# Out:
# saved to data/design_table.csv
#     process_entropy  number_of_traces  statespace_size process_type  \
# 0       min_entropy             100.0                5   memoryless
# 1       med_entropy             100.0                5   memoryless
# 2       max_entropy             100.0                5   memoryless
# 3       min_entropy             100.0               10   memoryless
# 4       med_entropy             100.0               10   memoryless
# ..              ...               ...              ...          ...
# 379     med_entropy             100.0                5       memory
# 380     max_entropy             100.0                5       memory
# 381     min_entropy             100.0               10       memory
# 382     med_entropy             100.0               10       memory
# 383     max_entropy             100.0               10       memory
#
#      process_memory  med_ent_n_transitions  inter_arrival_time  \
# 0               2.0                    3.0                 1.5
# 1               2.0                    3.0                 1.5
# 2               2.0                    3.0                 1.5
# 3               2.0                    3.0                 1.5
# 4               2.0                    3.0                 1.5
# ..              ...                    ...                 ...
# 379             4.0                    5.0                 1.5
# 380             4.0                    5.0                 1.5
# 381             4.0                    5.0                 1.5
# 382             4.0                    5.0                 1.5
# 383             4.0                    5.0                 1.5
#
#      process_stability_scale  resource_availability_p  \
# 0                        0.0                      0.5
# 1                        0.0                      0.5
# 2                        0.0                      0.5
# 3                        0.0                      0.5
# 4                        0.0                      0.5
# ..                       ...                      ...
# 379                      0.0                      0.5
# 380                      0.0                      0.5
# 381                      0.0                      0.5
# 382                      0.0                      0.5
# 383                      0.0                      0.5
#
#      resource_availability_n  resource_availability_m  \
# 0                        3.0                      0.0
# 1                        3.0                      0.0
# 2                        3.0                      0.0
# 3                        3.0                      0.0
# 4                        3.0                      0.0
# ..                       ...                      ...
# 379                      3.0                      0.0
# 380                      3.0                      0.0
# 381                      3.0                      0.0
# 382                      3.0                      0.0
# 383                      3.0                      0.0
#
#      activity_duration_lambda_range Deterministic_offset_W  \
# 0                               1.0               weekdays
# 1                               1.0               weekdays
# 2                               1.0               weekdays
# 3                               1.0               weekdays
# 4                               1.0               weekdays
# ..                              ...                    ...
# 379                             5.0               all-week
# 380                             5.0               all-week
# 381                             5.0               all-week
# 382                             5.0               all-week
# 383                             5.0               all-week
#
#      Deterministic_offset_u first_state_model  datetime_offset  \
# 0                       7.0              True             35.0
# 1                       7.0              True             35.0
# 2                       7.0              True             35.0
# 3                       7.0              True             35.0
# 4                       7.0              True             35.0
# ..                      ...               ...              ...
# 379                     7.0              True             35.0
# 380                     7.0              True             35.0
# 381                     7.0              True             35.0
# 382                     7.0              True             35.0
# 383                     7.0              True             35.0
#
#      num_replications  RUN  Done  Failure
# 0                 0.0    1     0        0
# 1                 0.0    2     0        0
# 2                 0.0    3     0        0
# 3                 0.0    4     0        0
# 4                 0.0    5     0        0
# ..                ...  ...   ...      ...
# 379               1.0  380     0        0
# 380               1.0  381     0        0
# 381               1.0  382     0        0
# 382               1.0  383     0        0
# 383               1.0  384     0        0
#
# [384 rows x 20 columns]

# %%
# inspect the resulting design table*
df
# Out:
#     process_entropy  number_of_traces  statespace_size process_type  \
# 0       min_entropy             100.0                5   memoryless
# 1       med_entropy             100.0                5   memoryless
# 2       max_entropy             100.0                5   memoryless
# 3       min_entropy             100.0               10   memoryless
# 4       med_entropy             100.0               10   memoryless
# ..              ...               ...              ...          ...
# 379     med_entropy             100.0                5       memory
# 380     max_entropy             100.0                5       memory
# 381     min_entropy             100.0               10       memory
# 382     med_entropy             100.0               10       memory
# 383     max_entropy             100.0               10       memory
#
#      process_memory  med_ent_n_transitions  inter_arrival_time  \
# 0               2.0                    3.0                 1.5
# 1               2.0                    3.0                 1.5
# 2               2.0                    3.0                 1.5
# 3               2.0                    3.0                 1.5
# 4               2.0                    3.0                 1.5
# ..              ...                    ...                 ...
# 379             4.0                    5.0                 1.5
# 380             4.0                    5.0                 1.5
# 381             4.0                    5.0                 1.5
# 382             4.0                    5.0                 1.5
# 383             4.0                    5.0                 1.5
#
#      process_stability_scale  resource_availability_p  \
# 0                        0.0                      0.5
# 1                        0.0                      0.5
# 2                        0.0                      0.5
# 3                        0.0                      0.5
# 4                        0.0                      0.5
# ..                       ...                      ...
# 379                      0.0                      0.5
# 380                      0.0                      0.5
# 381                      0.0                      0.5
# 382                      0.0                      0.5
# 383                      0.0                      0.5
#
#      resource_availability_n  resource_availability_m  \
# 0                        3.0                      0.0
# 1                        3.0                      0.0
# 2                        3.0                      0.0
# 3                        3.0                      0.0
# 4                        3.0                      0.0
# ..                       ...                      ...
# 379                      3.0                      0.0
# 380                      3.0                      0.0
# 381                      3.0                      0.0
# 382                      3.0                      0.0
# 383                      3.0                      0.0
#
#      activity_duration_lambda_range Deterministic_offset_W  \
# 0                               1.0               weekdays
# 1                               1.0               weekdays
# 2                               1.0               weekdays
# 3                               1.0               weekdays
# 4                               1.0               weekdays
# ..                              ...                    ...
# 379                             5.0               all-week
# 380                             5.0               all-week
# 381                             5.0               all-week
# 382                             5.0               all-week
# 383                             5.0               all-week
#
#      Deterministic_offset_u first_state_model  datetime_offset  \
# 0                       7.0              True             35.0
# 1                       7.0              True             35.0
# 2                       7.0              True             35.0
# 3                       7.0              True             35.0
# 4                       7.0              True             35.0
# ..                      ...               ...              ...
# 379                     7.0              True             35.0
# 380                     7.0              True             35.0
# 381                     7.0              True             35.0
# 382                     7.0              True             35.0
# 383                     7.0              True             35.0
#
#      num_replications  RUN  Done  Failure
# 0                 0.0    1     0        0
# 1                 0.0    2     0        0
# 2                 0.0    3     0        0
# 3                 0.0    4     0        0
# 4                 0.0    5     0        0
# ..                ...  ...   ...      ...
# 379               1.0  380     0        0
# 380               1.0  381     0        0
# 381               1.0  382     0        0
# 382               1.0  383     0        0
# 383               1.0  384     0        0
#
# [384 rows x 20 columns]

# %% [markdown]
# # Define training and evaluation functions
# Before running the experiments, you need to define model training and evaluation functions.
#
# In this example we train a first state model, which is a model using only the first observed event (state) to predict to total cycle-time. Setting first_state_model to False will produce a prefix-log, which can be used to predict remaining cycle-time from every observed event in the trace.
#
# Input for the training function is a dictionary named <b>Input_daata</b>, which contain the following:
# - x_train
# - x_test
# - y_train
# - y_test

# %%
curr_settings = df.loc[0]
curr_settings["run"] = 0

from SynBPS.simulation.simulation_pipeline import generate_eventlog
log = generate_eventlog(curr_settings=curr_settings, output_dir="data/")

# Prefix-log format:
from SynBPS.dataprep.memory_helperfunctions import prepare_data_f_memory
input_data = prepare_data_f_memory(log, verbose=False)

# First-state model:
from SynBPS.dataprep.firststate_helperfunctions import fs_prepare_dataset_from_memory'
input_data = fs_prepare_dataset_from_memory(input_data, sample=1.0, transform="log", first_state=True, verbose=True)
# Out:
# traces: 100
# eventlog saved to: data/0_Eventlog_min_entropy_memoryless.csv
# events: 500
# ids: 100
# Cases before dropping len=1: 100 cases 500 rows
# Cases after dropping len=1: 100 cases 500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 100
# longest trace is: 5
# Time format: 2005-01-03 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     e            1  2005-01-03 06:00:00 2005-01-03 14:10:29
# 1   1     f            2  2005-01-03 14:10:29 2005-01-03 17:53:26
# 2   1     d            3  2005-01-03 17:53:26 2005-01-03 21:56:51
# 3   1     c            4  2005-01-04 06:00:00 2005-01-04 09:16:55
# 4   1     b            5  2005-01-04 09:16:55 2005-01-06 04:32:01
# mode: event
# **********************************************************************************************************************************************************************************************************************************************************
# =======================================
# Log starts at: 2005-01-03 06:00:00
# Last event starts at: 2005-06-14 06:00:00
# Train-test split happens at: 2005-03-26 06:00:00
# =======================================
# 100
# 100
# 222
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 500
# after: 400
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 2000
# Generating case data
# done
# casedata:
#     num_events  caseid  distinct_events               start  \
# 0            5       1                5 2005-01-03 06:00:00
# 1            5       2                5 2005-01-03 06:00:00
# 2            5       3                5 2005-01-23 06:00:00
# 3            5       4                5 2005-01-23 06:00:00
# 4            5       5                5 2005-01-23 14:25:53
# ..         ...     ...              ...                 ...
# 95           5      96                5 2005-06-06 06:00:00
# 96           5      97                5 2005-06-07 06:00:00
# 97           5      98                5 2005-06-07 16:08:16
# 98           5      99                5 2005-06-12 06:00:00
# 99           5     100                5 2005-06-12 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 0  2005-01-04 09:16:55                  1                 11815
# 1  2005-01-04 17:42:52                  1                 42172
# 2  2005-01-23 16:17:23                  0                 37043
# 3  2005-01-23 11:31:39                  0                 19899
# 4  2005-01-25 06:23:42                  1                 57469
# ..                 ...                ...                   ...
# 95 2005-06-07 06:00:00                  1                     0
# 96 2005-06-08 06:00:00                  1                     0
# 97 2005-06-08 07:26:32                  0                 55096
# 98 2005-06-13 16:47:21                  1                 38841
# 99 2005-06-14 06:00:00                  2                     0
#
# [100 rows x 7 columns]
# Making casestats..
# casestats
#    num_events  caseid  distinct_events               start  \
# 0           5       1                5 2005-01-03 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 0 2005-01-04 09:16:55                  1                 11815
# casestats
#    num_events  caseid  distinct_events               start  \
# 0           5       1                5 2005-01-03 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 0 2005-01-04 09:16:55                  1                 11815
# casestats
#    num_events  caseid  distinct_events               start  \
# 0           5       1                5 2005-01-03 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 0 2005-01-04 09:16:55                  1                 11815
# casestats
#    num_events  caseid  distinct_events               start  \
# 0           5       1                5 2005-01-03 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 0 2005-01-04 09:16:55                  1                 11815
# casestats
#    num_events  caseid  distinct_events               start  \
# 1           5       2                5 2005-01-03 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 1 2005-01-04 17:42:52                  1                 42172
# casestats
#    num_events  caseid  distinct_events               start  \
# 1           5       2                5 2005-01-03 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 1 2005-01-04 17:42:52                  1                 42172
# casestats
#    num_events  caseid  distinct_events               start  \
# 1           5       2                5 2005-01-03 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 1 2005-01-04 17:42:52                  1                 42172
# casestats
#    num_events  caseid  distinct_events               start  \
# 1           5       2                5 2005-01-03 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 1 2005-01-04 17:42:52                  1                 42172
# casestats
#    num_events  caseid  distinct_events               start  \
# 2           5       3                5 2005-01-23 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 2 2005-01-23 16:17:23                  0                 37043
# casestats
#    num_events  caseid  distinct_events               start  \
# 2           5       3                5 2005-01-23 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 2 2005-01-23 16:17:23                  0                 37043
# casestats
#    num_events  caseid  distinct_events               start  \
# 2           5       3                5 2005-01-23 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 2 2005-01-23 16:17:23                  0                 37043
# casestats
#    num_events  caseid  distinct_events               start  \
# 2           5       3                5 2005-01-23 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 2 2005-01-23 16:17:23                  0                 37043
# casestats
#    num_events  caseid  distinct_events               start  \
# 3           5       4                5 2005-01-23 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 3 2005-01-23 11:31:39                  0                 19899
# casestats
#    num_events  caseid  distinct_events               start  \
# 3           5       4                5 2005-01-23 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 3 2005-01-23 11:31:39                  0                 19899
# casestats
#    num_events  caseid  distinct_events               start  \
# 3           5       4                5 2005-01-23 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 3 2005-01-23 11:31:39                  0                 19899
# casestats
#    num_events  caseid  distinct_events               start  \
# 3           5       4                5 2005-01-23 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 3 2005-01-23 11:31:39                  0                 19899
# casestats
#    num_events  caseid  distinct_events               start  \
# 4           5       5                5 2005-01-23 14:25:53
#
#                  stop  caseduration_days  caseduration_seconds
# 4 2005-01-25 06:23:42                  1                 57469
# casestats
#    num_events  caseid  distinct_events               start  \
# 4           5       5                5 2005-01-23 14:25:53
#
#                  stop  caseduration_days  caseduration_seconds
# 4 2005-01-25 06:23:42                  1                 57469
# casestats
#    num_events  caseid  distinct_events               start  \
# 4           5       5                5 2005-01-23 14:25:53
#
#                  stop  caseduration_days  caseduration_seconds
# 4 2005-01-25 06:23:42                  1                 57469
# casestats
#    num_events  caseid  distinct_events               start  \
# 4           5       5                5 2005-01-23 14:25:53
#
#                  stop  caseduration_days  caseduration_seconds
# 4 2005-01-25 06:23:42                  1                 57469
# casestats
#    num_events  caseid  distinct_events               start  \
# 5           5       6                5 2005-01-27 12:06:48
#
#                  stop  caseduration_days  caseduration_seconds
# 5 2005-01-31 06:00:00                  3                 64392
# casestats
#    num_events  caseid  distinct_events               start  \
# 5           5       6                5 2005-01-27 12:06:48
#
#                  stop  caseduration_days  caseduration_seconds
# 5 2005-01-31 06:00:00                  3                 64392
# casestats
#    num_events  caseid  distinct_events               start  \
# 5           5       6                5 2005-01-27 12:06:48
#
#                  stop  caseduration_days  caseduration_seconds
# 5 2005-01-31 06:00:00                  3                 64392
# casestats
#    num_events  caseid  distinct_events               start  \
# 5           5       6                5 2005-01-27 12:06:48
#
#                  stop  caseduration_days  caseduration_seconds
# 5 2005-01-31 06:00:00                  3                 64392
# casestats
#    num_events  caseid  distinct_events               start  \
# 6           5       7                5 2005-01-31 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 6 2005-02-01 11:46:01                  1                 20761
# casestats
#    num_events  caseid  distinct_events               start  \
# 6           5       7                5 2005-01-31 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 6 2005-02-01 11:46:01                  1                 20761
# casestats
#    num_events  caseid  distinct_events               start  \
# 6           5       7                5 2005-01-31 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 6 2005-02-01 11:46:01                  1                 20761
# casestats
#    num_events  caseid  distinct_events               start  \
# 6           5       7                5 2005-01-31 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 6 2005-02-01 11:46:01                  1                 20761
# casestats
#    num_events  caseid  distinct_events               start  \
# 7           5       8                5 2005-02-01 07:59:38
#
#                  stop  caseduration_days  caseduration_seconds
# 7 2005-02-02 08:10:33                  1                   655
# casestats
#    num_events  caseid  distinct_events               start  \
# 7           5       8                5 2005-02-01 07:59:38
#
#                  stop  caseduration_days  caseduration_seconds
# 7 2005-02-02 08:10:33                  1                   655
# casestats
#    num_events  caseid  distinct_events               start  \
# 7           5       8                5 2005-02-01 07:59:38
#
#                  stop  caseduration_days  caseduration_seconds
# 7 2005-02-02 08:10:33                  1                   655
# casestats
#    num_events  caseid  distinct_events               start  \
# 7           5       8                5 2005-02-01 07:59:38
#
#                  stop  caseduration_days  caseduration_seconds
# 7 2005-02-02 08:10:33                  1                   655
# casestats
#    num_events  caseid  distinct_events               start  \
# 8           5       9                5 2005-02-02 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 8 2005-02-03 15:55:27                  1                 35727
# casestats
#    num_events  caseid  distinct_events               start  \
# 8           5       9                5 2005-02-02 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 8 2005-02-03 15:55:27                  1                 35727
# casestats
#    num_events  caseid  distinct_events               start  \
# 8           5       9                5 2005-02-02 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 8 2005-02-03 15:55:27                  1                 35727
# casestats
#    num_events  caseid  distinct_events               start  \
# 8           5       9                5 2005-02-02 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 8 2005-02-03 15:55:27                  1                 35727
# casestats
#    num_events  caseid  distinct_events               start  \
# 9           5      10                5 2005-02-02 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 9 2005-02-06 07:00:09                  4                  3609
# casestats
#    num_events  caseid  distinct_events               start  \
# 9           5      10                5 2005-02-02 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 9 2005-02-06 07:00:09                  4                  3609
# casestats
#    num_events  caseid  distinct_events               start  \
# 9           5      10                5 2005-02-02 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 9 2005-02-06 07:00:09                  4                  3609
# casestats
#    num_events  caseid  distinct_events               start  \
# 9           5      10                5 2005-02-02 06:00:00
#
#                  stop  caseduration_days  caseduration_seconds
# 9 2005-02-06 07:00:09                  4                  3609
# casestats
#     num_events  caseid  distinct_events               start  \
# 10           5      11                5 2005-02-02 14:50:22
#
#                   stop  caseduration_days  caseduration_seconds
# 10 2005-02-06 06:41:33                  3                 57071
# casestats
#     num_events  caseid  distinct_events               start  \
# 10           5      11                5 2005-02-02 14:50:22
#
#                   stop  caseduration_days  caseduration_seconds
# 10 2005-02-06 06:41:33                  3                 57071
# casestats
#     num_events  caseid  distinct_events               start  \
# 10           5      11                5 2005-02-02 14:50:22
#
#                   stop  caseduration_days  caseduration_seconds
# 10 2005-02-06 06:41:33                  3                 57071
# casestats
#     num_events  caseid  distinct_events               start  \
# 10           5      11                5 2005-02-02 14:50:22
#
#                   stop  caseduration_days  caseduration_seconds
# 10 2005-02-06 06:41:33                  3                 57071
# casestats
#     num_events  caseid  distinct_events               start  \
# 11           5      12                5 2005-02-03 12:41:56
#
#                   stop  caseduration_days  caseduration_seconds
# 11 2005-02-06 06:00:00                  2                 62284
# casestats
#     num_events  caseid  distinct_events               start  \
# 11           5      12                5 2005-02-03 12:41:56
#
#                   stop  caseduration_days  caseduration_seconds
# 11 2005-02-06 06:00:00                  2                 62284
# casestats
#     num_events  caseid  distinct_events               start  \
# 11           5      12                5 2005-02-03 12:41:56
#
#                   stop  caseduration_days  caseduration_seconds
# 11 2005-02-06 06:00:00                  2                 62284
# casestats
#     num_events  caseid  distinct_events               start  \
# 11           5      12                5 2005-02-03 12:41:56
#
#                   stop  caseduration_days  caseduration_seconds
# 11 2005-02-06 06:00:00                  2                 62284
# casestats
#     num_events  caseid  distinct_events               start  \
# 12           5      13                5 2005-01-03 11:07:28
#
#                   stop  caseduration_days  caseduration_seconds
# 12 2005-01-04 14:57:36                  1                 13808
# casestats
#     num_events  caseid  distinct_events               start  \
# 12           5      13                5 2005-01-03 11:07:28
#
#                   stop  caseduration_days  caseduration_seconds
# 12 2005-01-04 14:57:36                  1                 13808
# casestats
#     num_events  caseid  distinct_events               start  \
# 12           5      13                5 2005-01-03 11:07:28
#
#                   stop  caseduration_days  caseduration_seconds
# 12 2005-01-04 14:57:36                  1                 13808
# casestats
#     num_events  caseid  distinct_events               start  \
# 12           5      13                5 2005-01-03 11:07:28
#
#                   stop  caseduration_days  caseduration_seconds
# 12 2005-01-04 14:57:36                  1                 13808
# casestats
#     num_events  caseid  distinct_events               start  \
# 13           5      14                5 2005-02-06 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 13 2005-02-07 17:59:02                  1                 43142
# casestats
#     num_events  caseid  distinct_events               start  \
# 13           5      14                5 2005-02-06 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 13 2005-02-07 17:59:02                  1                 43142
# casestats
#     num_events  caseid  distinct_events               start  \
# 13           5      14                5 2005-02-06 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 13 2005-02-07 17:59:02                  1                 43142
# casestats
#     num_events  caseid  distinct_events               start  \
# 13           5      14                5 2005-02-06 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 13 2005-02-07 17:59:02                  1                 43142
# casestats
#     num_events  caseid  distinct_events               start  \
# 14           5      15                5 2005-02-06 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 14 2005-02-07 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 14           5      15                5 2005-02-06 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 14 2005-02-07 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 14           5      15                5 2005-02-06 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 14 2005-02-07 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 14           5      15                5 2005-02-06 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 14 2005-02-07 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 15           5      16                5 2005-02-06 10:12:09
#
#                   stop  caseduration_days  caseduration_seconds
# 15 2005-02-07 06:26:23                  0                 72854
# casestats
#     num_events  caseid  distinct_events               start  \
# 15           5      16                5 2005-02-06 10:12:09
#
#                   stop  caseduration_days  caseduration_seconds
# 15 2005-02-07 06:26:23                  0                 72854
# casestats
#     num_events  caseid  distinct_events               start  \
# 15           5      16                5 2005-02-06 10:12:09
#
#                   stop  caseduration_days  caseduration_seconds
# 15 2005-02-07 06:26:23                  0                 72854
# casestats
#     num_events  caseid  distinct_events               start  \
# 15           5      16                5 2005-02-06 10:12:09
#
#                   stop  caseduration_days  caseduration_seconds
# 15 2005-02-07 06:26:23                  0                 72854
# casestats
#     num_events  caseid  distinct_events               start  \
# 16           5      17                5 2005-02-08 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 16 2005-02-13 06:00:00                  5                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 16           5      17                5 2005-02-08 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 16 2005-02-13 06:00:00                  5                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 16           5      17                5 2005-02-08 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 16 2005-02-13 06:00:00                  5                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 16           5      17                5 2005-02-08 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 16 2005-02-13 06:00:00                  5                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 17           5      18                5 2005-02-08 06:57:10
#
#                   stop  caseduration_days  caseduration_seconds
# 17 2005-02-09 06:00:00                  0                 82970
# casestats
#     num_events  caseid  distinct_events               start  \
# 17           5      18                5 2005-02-08 06:57:10
#
#                   stop  caseduration_days  caseduration_seconds
# 17 2005-02-09 06:00:00                  0                 82970
# casestats
#     num_events  caseid  distinct_events               start  \
# 17           5      18                5 2005-02-08 06:57:10
#
#                   stop  caseduration_days  caseduration_seconds
# 17 2005-02-09 06:00:00                  0                 82970
# casestats
#     num_events  caseid  distinct_events               start  \
# 17           5      18                5 2005-02-08 06:57:10
#
#                   stop  caseduration_days  caseduration_seconds
# 17 2005-02-09 06:00:00                  0                 82970
# casestats
#     num_events  caseid  distinct_events               start  \
# 18           5      19                5 2005-02-13 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 18 2005-02-14 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 18           5      19                5 2005-02-13 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 18 2005-02-14 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 18           5      19                5 2005-02-13 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 18 2005-02-14 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 18           5      19                5 2005-02-13 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 18 2005-02-14 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 19           5      20                5 2005-02-17 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 19 2005-02-20 09:07:57                  3                 11277
# casestats
#     num_events  caseid  distinct_events               start  \
# 19           5      20                5 2005-02-17 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 19 2005-02-20 09:07:57                  3                 11277
# casestats
#     num_events  caseid  distinct_events               start  \
# 19           5      20                5 2005-02-17 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 19 2005-02-20 09:07:57                  3                 11277
# casestats
#     num_events  caseid  distinct_events               start  \
# 19           5      20                5 2005-02-17 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 19 2005-02-20 09:07:57                  3                 11277
# casestats
#     num_events  caseid  distinct_events               start  \
# 20           5      21                5 2005-02-17 06:14:52
#
#                   stop  caseduration_days  caseduration_seconds
# 20 2005-02-17 14:40:23                  0                 30331
# casestats
#     num_events  caseid  distinct_events               start  \
# 20           5      21                5 2005-02-17 06:14:52
#
#                   stop  caseduration_days  caseduration_seconds
# 20 2005-02-17 14:40:23                  0                 30331
# casestats
#     num_events  caseid  distinct_events               start  \
# 20           5      21                5 2005-02-17 06:14:52
#
#                   stop  caseduration_days  caseduration_seconds
# 20 2005-02-17 14:40:23                  0                 30331
# casestats
#     num_events  caseid  distinct_events               start  \
# 20           5      21                5 2005-02-17 06:14:52
#
#                   stop  caseduration_days  caseduration_seconds
# 20 2005-02-17 14:40:23                  0                 30331
# casestats
#     num_events  caseid  distinct_events               start  \
# 21           5      22                5 2005-02-20 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 21 2005-02-22 08:01:28                  2                  7288
# casestats
#     num_events  caseid  distinct_events               start  \
# 21           5      22                5 2005-02-20 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 21 2005-02-22 08:01:28                  2                  7288
# casestats
#     num_events  caseid  distinct_events               start  \
# 21           5      22                5 2005-02-20 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 21 2005-02-22 08:01:28                  2                  7288
# casestats
#     num_events  caseid  distinct_events               start  \
# 21           5      22                5 2005-02-20 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 21 2005-02-22 08:01:28                  2                  7288
# casestats
#     num_events  caseid  distinct_events               start  \
# 22           5      23                5 2005-02-20 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 22 2005-02-22 08:40:42                  2                  9642
# casestats
#     num_events  caseid  distinct_events               start  \
# 22           5      23                5 2005-02-20 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 22 2005-02-22 08:40:42                  2                  9642
# casestats
#     num_events  caseid  distinct_events               start  \
# 22           5      23                5 2005-02-20 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 22 2005-02-22 08:40:42                  2                  9642
# casestats
#     num_events  caseid  distinct_events               start  \
# 22           5      23                5 2005-02-20 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 22 2005-02-22 08:40:42                  2                  9642
# casestats
#     num_events  caseid  distinct_events               start  \
# 23           5      24                5 2005-01-03 17:38:23
#
#                   stop  caseduration_days  caseduration_seconds
# 23 2005-01-04 14:50:18                  0                 76315
# casestats
#     num_events  caseid  distinct_events               start  \
# 23           5      24                5 2005-01-03 17:38:23
#
#                   stop  caseduration_days  caseduration_seconds
# 23 2005-01-04 14:50:18                  0                 76315
# casestats
#     num_events  caseid  distinct_events               start  \
# 23           5      24                5 2005-01-03 17:38:23
#
#                   stop  caseduration_days  caseduration_seconds
# 23 2005-01-04 14:50:18                  0                 76315
# casestats
#     num_events  caseid  distinct_events               start  \
# 23           5      24                5 2005-01-03 17:38:23
#
#                   stop  caseduration_days  caseduration_seconds
# 23 2005-01-04 14:50:18                  0                 76315
# casestats
#     num_events  caseid  distinct_events               start  \
# 24           5      25                5 2005-02-20 17:42:26
#
#                   stop  caseduration_days  caseduration_seconds
# 24 2005-02-23 06:00:00                  2                 44254
# casestats
#     num_events  caseid  distinct_events               start  \
# 24           5      25                5 2005-02-20 17:42:26
#
#                   stop  caseduration_days  caseduration_seconds
# 24 2005-02-23 06:00:00                  2                 44254
# casestats
#     num_events  caseid  distinct_events               start  \
# 24           5      25                5 2005-02-20 17:42:26
#
#                   stop  caseduration_days  caseduration_seconds
# 24 2005-02-23 06:00:00                  2                 44254
# casestats
#     num_events  caseid  distinct_events               start  \
# 24           5      25                5 2005-02-20 17:42:26
#
#                   stop  caseduration_days  caseduration_seconds
# 24 2005-02-23 06:00:00                  2                 44254
# casestats
#     num_events  caseid  distinct_events               start  \
# 25           5      26                5 2005-02-23 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 25 2005-02-24 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 25           5      26                5 2005-02-23 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 25 2005-02-24 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 25           5      26                5 2005-02-23 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 25 2005-02-24 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 25           5      26                5 2005-02-23 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 25 2005-02-24 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 26           5      27                5 2005-02-24 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 26 2005-02-27 12:39:36                  3                 23976
# casestats
#     num_events  caseid  distinct_events               start  \
# 26           5      27                5 2005-02-24 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 26 2005-02-27 12:39:36                  3                 23976
# casestats
#     num_events  caseid  distinct_events               start  \
# 26           5      27                5 2005-02-24 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 26 2005-02-27 12:39:36                  3                 23976
# casestats
#     num_events  caseid  distinct_events               start  \
# 26           5      27                5 2005-02-24 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 26 2005-02-27 12:39:36                  3                 23976
# casestats
#     num_events  caseid  distinct_events               start  \
# 27           5      28                5 2005-02-27 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 27 2005-02-28 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 27           5      28                5 2005-02-27 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 27 2005-02-28 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 27           5      28                5 2005-02-27 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 27 2005-02-28 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 27           5      28                5 2005-02-27 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 27 2005-02-28 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 28           5      29                5 2005-03-03 09:07:22
#
#                   stop  caseduration_days  caseduration_seconds
# 28 2005-03-06 11:18:40                  3                  7878
# casestats
#     num_events  caseid  distinct_events               start  \
# 28           5      29                5 2005-03-03 09:07:22
#
#                   stop  caseduration_days  caseduration_seconds
# 28 2005-03-06 11:18:40                  3                  7878
# casestats
#     num_events  caseid  distinct_events               start  \
# 28           5      29                5 2005-03-03 09:07:22
#
#                   stop  caseduration_days  caseduration_seconds
# 28 2005-03-06 11:18:40                  3                  7878
# casestats
#     num_events  caseid  distinct_events               start  \
# 28           5      29                5 2005-03-03 09:07:22
#
#                   stop  caseduration_days  caseduration_seconds
# 28 2005-03-06 11:18:40                  3                  7878
# casestats
#     num_events  caseid  distinct_events               start  \
# 29           5      30                5 2005-03-03 12:00:55
#
#                   stop  caseduration_days  caseduration_seconds
# 29 2005-03-07 07:01:33                  3                 68438
# casestats
#     num_events  caseid  distinct_events               start  \
# 29           5      30                5 2005-03-03 12:00:55
#
#                   stop  caseduration_days  caseduration_seconds
# 29 2005-03-07 07:01:33                  3                 68438
# casestats
#     num_events  caseid  distinct_events               start  \
# 29           5      30                5 2005-03-03 12:00:55
#
#                   stop  caseduration_days  caseduration_seconds
# 29 2005-03-07 07:01:33                  3                 68438
# casestats
#     num_events  caseid  distinct_events               start  \
# 29           5      30                5 2005-03-03 12:00:55
#
#                   stop  caseduration_days  caseduration_seconds
# 29 2005-03-07 07:01:33                  3                 68438
# casestats
#     num_events  caseid  distinct_events               start  \
# 30           5      31                5 2005-03-06 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 30 2005-03-08 14:17:09                  2                 29829
# casestats
#     num_events  caseid  distinct_events               start  \
# 30           5      31                5 2005-03-06 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 30 2005-03-08 14:17:09                  2                 29829
# casestats
#     num_events  caseid  distinct_events               start  \
# 30           5      31                5 2005-03-06 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 30 2005-03-08 14:17:09                  2                 29829
# casestats
#     num_events  caseid  distinct_events               start  \
# 30           5      31                5 2005-03-06 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 30 2005-03-08 14:17:09                  2                 29829
# casestats
#     num_events  caseid  distinct_events               start  \
# 31           5      32                5 2005-03-07 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 31 2005-03-07 10:28:35                  0                 16115
# casestats
#     num_events  caseid  distinct_events               start  \
# 31           5      32                5 2005-03-07 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 31 2005-03-07 10:28:35                  0                 16115
# casestats
#     num_events  caseid  distinct_events               start  \
# 31           5      32                5 2005-03-07 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 31 2005-03-07 10:28:35                  0                 16115
# casestats
#     num_events  caseid  distinct_events               start  \
# 31           5      32                5 2005-03-07 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 31 2005-03-07 10:28:35                  0                 16115
# casestats
#     num_events  caseid  distinct_events               start  \
# 32           5      33                5 2005-03-13 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 32 2005-03-15 07:21:11                  2                  4871
# casestats
#     num_events  caseid  distinct_events               start  \
# 32           5      33                5 2005-03-13 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 32 2005-03-15 07:21:11                  2                  4871
# casestats
#     num_events  caseid  distinct_events               start  \
# 32           5      33                5 2005-03-13 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 32 2005-03-15 07:21:11                  2                  4871
# casestats
#     num_events  caseid  distinct_events               start  \
# 32           5      33                5 2005-03-13 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 32 2005-03-15 07:21:11                  2                  4871
# casestats
#     num_events  caseid  distinct_events               start  \
# 33           5      34                5 2005-03-14 15:53:20
#
#                   stop  caseduration_days  caseduration_seconds
# 33 2005-03-15 11:17:10                  0                 69830
# casestats
#     num_events  caseid  distinct_events               start  \
# 33           5      34                5 2005-03-14 15:53:20
#
#                   stop  caseduration_days  caseduration_seconds
# 33 2005-03-15 11:17:10                  0                 69830
# casestats
#     num_events  caseid  distinct_events               start  \
# 33           5      34                5 2005-03-14 15:53:20
#
#                   stop  caseduration_days  caseduration_seconds
# 33 2005-03-15 11:17:10                  0                 69830
# casestats
#     num_events  caseid  distinct_events               start  \
# 33           5      34                5 2005-03-14 15:53:20
#
#                   stop  caseduration_days  caseduration_seconds
# 33 2005-03-15 11:17:10                  0                 69830
# casestats
#     num_events  caseid  distinct_events               start  \
# 34           5      35                5 2005-01-04 08:02:17
#
#                   stop  caseduration_days  caseduration_seconds
# 34 2005-01-05 06:00:00                  0                 79063
# casestats
#     num_events  caseid  distinct_events               start  \
# 34           5      35                5 2005-01-04 08:02:17
#
#                   stop  caseduration_days  caseduration_seconds
# 34 2005-01-05 06:00:00                  0                 79063
# casestats
#     num_events  caseid  distinct_events               start  \
# 34           5      35                5 2005-01-04 08:02:17
#
#                   stop  caseduration_days  caseduration_seconds
# 34 2005-01-05 06:00:00                  0                 79063
# casestats
#     num_events  caseid  distinct_events               start  \
# 34           5      35                5 2005-01-04 08:02:17
#
#                   stop  caseduration_days  caseduration_seconds
# 34 2005-01-05 06:00:00                  0                 79063
# casestats
#     num_events  caseid  distinct_events               start  \
# 35           5      36                5 2005-03-15 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 35 2005-03-16 14:11:08                  1                 29468
# casestats
#     num_events  caseid  distinct_events               start  \
# 35           5      36                5 2005-03-15 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 35 2005-03-16 14:11:08                  1                 29468
# casestats
#     num_events  caseid  distinct_events               start  \
# 35           5      36                5 2005-03-15 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 35 2005-03-16 14:11:08                  1                 29468
# casestats
#     num_events  caseid  distinct_events               start  \
# 35           5      36                5 2005-03-15 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 35 2005-03-16 14:11:08                  1                 29468
# casestats
#     num_events  caseid  distinct_events               start  \
# 36           5      37                5 2005-03-21 15:38:53
#
#                   stop  caseduration_days  caseduration_seconds
# 36 2005-03-24 06:00:00                  2                 51667
# casestats
#     num_events  caseid  distinct_events               start  \
# 36           5      37                5 2005-03-21 15:38:53
#
#                   stop  caseduration_days  caseduration_seconds
# 36 2005-03-24 06:00:00                  2                 51667
# casestats
#     num_events  caseid  distinct_events               start  \
# 36           5      37                5 2005-03-21 15:38:53
#
#                   stop  caseduration_days  caseduration_seconds
# 36 2005-03-24 06:00:00                  2                 51667
# casestats
#     num_events  caseid  distinct_events               start  \
# 36           5      37                5 2005-03-21 15:38:53
#
#                   stop  caseduration_days  caseduration_seconds
# 36 2005-03-24 06:00:00                  2                 51667
# casestats
#     num_events  caseid  distinct_events               start  \
# 37           5      38                5 2005-03-22 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 37 2005-03-24 09:59:54                  2                 14394
# casestats
#     num_events  caseid  distinct_events               start  \
# 37           5      38                5 2005-03-22 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 37 2005-03-24 09:59:54                  2                 14394
# casestats
#     num_events  caseid  distinct_events               start  \
# 37           5      38                5 2005-03-22 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 37 2005-03-24 09:59:54                  2                 14394
# casestats
#     num_events  caseid  distinct_events               start  \
# 37           5      38                5 2005-03-22 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 37 2005-03-24 09:59:54                  2                 14394
# casestats
#     num_events  caseid  distinct_events               start  \
# 38           5      39                5 2005-03-23 08:46:47
#
#                   stop  caseduration_days  caseduration_seconds
# 38 2005-03-27 06:00:00                  3                 76393
# casestats
#     num_events  caseid  distinct_events               start  \
# 38           5      39                5 2005-03-23 08:46:47
#
#                   stop  caseduration_days  caseduration_seconds
# 38 2005-03-27 06:00:00                  3                 76393
# casestats
#     num_events  caseid  distinct_events               start  \
# 38           5      39                5 2005-03-23 08:46:47
#
#                   stop  caseduration_days  caseduration_seconds
# 38 2005-03-27 06:00:00                  3                 76393
# casestats
#     num_events  caseid  distinct_events               start  \
# 38           5      39                5 2005-03-23 08:46:47
#
#                   stop  caseduration_days  caseduration_seconds
# 38 2005-03-27 06:00:00                  3                 76393
# casestats
#     num_events  caseid  distinct_events               start  \
# 39           5      40                5 2005-03-24 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 39 2005-03-27 16:34:47                  3                 38087
# casestats
#     num_events  caseid  distinct_events               start  \
# 39           5      40                5 2005-03-24 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 39 2005-03-27 16:34:47                  3                 38087
# casestats
#     num_events  caseid  distinct_events               start  \
# 39           5      40                5 2005-03-24 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 39 2005-03-27 16:34:47                  3                 38087
# casestats
#     num_events  caseid  distinct_events               start  \
# 39           5      40                5 2005-03-24 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 39 2005-03-27 16:34:47                  3                 38087
# casestats
#     num_events  caseid  distinct_events               start  \
# 40           5      41                5 2005-03-27 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 40 2005-03-28 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 40           5      41                5 2005-03-27 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 40 2005-03-28 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 40           5      41                5 2005-03-27 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 40 2005-03-28 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 40           5      41                5 2005-03-27 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 40 2005-03-28 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 41           5      42                5 2005-03-27 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 41 2005-03-29 06:00:00                  2                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 41           5      42                5 2005-03-27 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 41 2005-03-29 06:00:00                  2                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 41           5      42                5 2005-03-27 06:00:00
#
# ...
# 85           5      86                5 2005-05-18 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 85 2005-05-19 12:49:36                  1                 24576
# casestats
#     num_events  caseid  distinct_events               start  \
# 85           5      86                5 2005-05-18 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 85 2005-05-19 12:49:36                  1                 24576
# casestats
#     num_events  caseid  distinct_events               start  \
# 86           5      87                5 2005-05-23 07:54:47
#
#                   stop  caseduration_days  caseduration_seconds
# 86 2005-05-24 06:00:00                  0                 79513
# casestats
#     num_events  caseid  distinct_events               start  \
# 86           5      87                5 2005-05-23 07:54:47
#
#                   stop  caseduration_days  caseduration_seconds
# 86 2005-05-24 06:00:00                  0                 79513
# casestats
#     num_events  caseid  distinct_events               start  \
# 86           5      87                5 2005-05-23 07:54:47
#
#                   stop  caseduration_days  caseduration_seconds
# 86 2005-05-24 06:00:00                  0                 79513
# casestats
#     num_events  caseid  distinct_events               start  \
# 86           5      87                5 2005-05-23 07:54:47
#
#                   stop  caseduration_days  caseduration_seconds
# 86 2005-05-24 06:00:00                  0                 79513
# casestats
#     num_events  caseid  distinct_events               start  \
# 87           5      88                5 2005-05-24 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 87 2005-05-24 16:41:52                  0                 38512
# casestats
#     num_events  caseid  distinct_events               start  \
# 87           5      88                5 2005-05-24 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 87 2005-05-24 16:41:52                  0                 38512
# casestats
#     num_events  caseid  distinct_events               start  \
# 87           5      88                5 2005-05-24 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 87 2005-05-24 16:41:52                  0                 38512
# casestats
#     num_events  caseid  distinct_events               start  \
# 87           5      88                5 2005-05-24 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 87 2005-05-24 16:41:52                  0                 38512
# casestats
#     num_events  caseid  distinct_events               start  \
# 88           5      89                5 2005-05-24 12:47:07
#
#                   stop  caseduration_days  caseduration_seconds
# 88 2005-05-26 09:21:17                  1                 74050
# casestats
#     num_events  caseid  distinct_events               start  \
# 88           5      89                5 2005-05-24 12:47:07
#
#                   stop  caseduration_days  caseduration_seconds
# 88 2005-05-26 09:21:17                  1                 74050
# casestats
#     num_events  caseid  distinct_events               start  \
# 88           5      89                5 2005-05-24 12:47:07
#
#                   stop  caseduration_days  caseduration_seconds
# 88 2005-05-26 09:21:17                  1                 74050
# casestats
#     num_events  caseid  distinct_events               start  \
# 88           5      89                5 2005-05-24 12:47:07
#
#                   stop  caseduration_days  caseduration_seconds
# 88 2005-05-26 09:21:17                  1                 74050
# casestats
#     num_events  caseid  distinct_events               start  \
# 89           5      90                5 2005-01-23 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 89 2005-01-23 17:33:09                  0                 41589
# casestats
#     num_events  caseid  distinct_events               start  \
# 89           5      90                5 2005-01-23 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 89 2005-01-23 17:33:09                  0                 41589
# casestats
#     num_events  caseid  distinct_events               start  \
# 89           5      90                5 2005-01-23 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 89 2005-01-23 17:33:09                  0                 41589
# casestats
#     num_events  caseid  distinct_events               start  \
# 89           5      90                5 2005-01-23 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 89 2005-01-23 17:33:09                  0                 41589
# casestats
#     num_events  caseid  distinct_events               start  \
# 90           5      91                5 2005-05-31 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 90 2005-06-01 07:04:01                  1                  3841
# casestats
#     num_events  caseid  distinct_events               start  \
# 90           5      91                5 2005-05-31 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 90 2005-06-01 07:04:01                  1                  3841
# casestats
#     num_events  caseid  distinct_events               start  \
# 90           5      91                5 2005-05-31 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 90 2005-06-01 07:04:01                  1                  3841
# casestats
#     num_events  caseid  distinct_events               start  \
# 90           5      91                5 2005-05-31 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 90 2005-06-01 07:04:01                  1                  3841
# casestats
#     num_events  caseid  distinct_events               start  \
# 91           5      92                5 2005-05-31 06:14:22
#
#                   stop  caseduration_days  caseduration_seconds
# 91 2005-06-02 06:15:31                  2                    69
# casestats
#     num_events  caseid  distinct_events               start  \
# 91           5      92                5 2005-05-31 06:14:22
#
#                   stop  caseduration_days  caseduration_seconds
# 91 2005-06-02 06:15:31                  2                    69
# casestats
#     num_events  caseid  distinct_events               start  \
# 91           5      92                5 2005-05-31 06:14:22
#
#                   stop  caseduration_days  caseduration_seconds
# 91 2005-06-02 06:15:31                  2                    69
# casestats
#     num_events  caseid  distinct_events               start  \
# 91           5      92                5 2005-05-31 06:14:22
#
#                   stop  caseduration_days  caseduration_seconds
# 91 2005-06-02 06:15:31                  2                    69
# casestats
#     num_events  caseid  distinct_events               start  \
# 92           5      93                5 2005-06-01 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 92 2005-06-01 14:51:59                  0                 31919
# casestats
#     num_events  caseid  distinct_events               start  \
# 92           5      93                5 2005-06-01 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 92 2005-06-01 14:51:59                  0                 31919
# casestats
#     num_events  caseid  distinct_events               start  \
# 92           5      93                5 2005-06-01 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 92 2005-06-01 14:51:59                  0                 31919
# casestats
#     num_events  caseid  distinct_events               start  \
# 92           5      93                5 2005-06-01 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 92 2005-06-01 14:51:59                  0                 31919
# casestats
#     num_events  caseid  distinct_events               start  \
# 93           5      94                5 2005-06-01 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 93 2005-06-02 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 93           5      94                5 2005-06-01 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 93 2005-06-02 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 93           5      94                5 2005-06-01 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 93 2005-06-02 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 93           5      94                5 2005-06-01 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 93 2005-06-02 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 94           5      95                5 2005-06-05 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 94 2005-06-06 11:57:05                  1                 21425
# casestats
#     num_events  caseid  distinct_events               start  \
# 94           5      95                5 2005-06-05 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 94 2005-06-06 11:57:05                  1                 21425
# casestats
#     num_events  caseid  distinct_events               start  \
# 94           5      95                5 2005-06-05 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 94 2005-06-06 11:57:05                  1                 21425
# casestats
#     num_events  caseid  distinct_events               start  \
# 94           5      95                5 2005-06-05 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 94 2005-06-06 11:57:05                  1                 21425
# casestats
#     num_events  caseid  distinct_events               start  \
# 95           5      96                5 2005-06-06 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 95 2005-06-07 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 95           5      96                5 2005-06-06 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 95 2005-06-07 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 95           5      96                5 2005-06-06 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 95 2005-06-07 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 95           5      96                5 2005-06-06 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 95 2005-06-07 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 96           5      97                5 2005-06-07 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 96 2005-06-08 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 96           5      97                5 2005-06-07 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 96 2005-06-08 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 96           5      97                5 2005-06-07 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 96 2005-06-08 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 96           5      97                5 2005-06-07 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 96 2005-06-08 06:00:00                  1                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 97           5      98                5 2005-06-07 16:08:16
#
#                   stop  caseduration_days  caseduration_seconds
# 97 2005-06-08 07:26:32                  0                 55096
# casestats
#     num_events  caseid  distinct_events               start  \
# 97           5      98                5 2005-06-07 16:08:16
#
#                   stop  caseduration_days  caseduration_seconds
# 97 2005-06-08 07:26:32                  0                 55096
# casestats
#     num_events  caseid  distinct_events               start  \
# 97           5      98                5 2005-06-07 16:08:16
#
#                   stop  caseduration_days  caseduration_seconds
# 97 2005-06-08 07:26:32                  0                 55096
# casestats
#     num_events  caseid  distinct_events               start  \
# 97           5      98                5 2005-06-07 16:08:16
#
#                   stop  caseduration_days  caseduration_seconds
# 97 2005-06-08 07:26:32                  0                 55096
# casestats
#     num_events  caseid  distinct_events               start  \
# 98           5      99                5 2005-06-12 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 98 2005-06-13 16:47:21                  1                 38841
# casestats
#     num_events  caseid  distinct_events               start  \
# 98           5      99                5 2005-06-12 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 98 2005-06-13 16:47:21                  1                 38841
# casestats
#     num_events  caseid  distinct_events               start  \
# 98           5      99                5 2005-06-12 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 98 2005-06-13 16:47:21                  1                 38841
# casestats
#     num_events  caseid  distinct_events               start  \
# 98           5      99                5 2005-06-12 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 98 2005-06-13 16:47:21                  1                 38841
# casestats
#     num_events  caseid  distinct_events               start  \
# 99           5     100                5 2005-06-12 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 99 2005-06-14 06:00:00                  2                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 99           5     100                5 2005-06-12 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 99 2005-06-14 06:00:00                  2                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 99           5     100                5 2005-06-12 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 99 2005-06-14 06:00:00                  2                     0
# casestats
#     num_events  caseid  distinct_events               start  \
# 99           5     100                5 2005-06-12 06:00:00
#
#                   stop  caseduration_days  caseduration_seconds
# 99 2005-06-14 06:00:00                  2                     0
# Done.
# merging..
# 2000
# 2000
# 400
# 400
# 400
# 400
# 400
# 400
# reshaping..
# Trainset size (with prefixes of  5 ): 180
# Testset size (with prefixes of  5 ): 220
# ==========================================
# X: observations, timesteps, vars
# (180, 5, 11)
# y_train: observations, labels
# (180, 1)
# y_t_train: observations, labels
# (180, 1)
# y_a_train: observations, labels
# (180, 4)
# Inference train: 180
# Inference test:  220
# (180, 11)
# (180,)
# (220, 11)
# (220,)

# %%
input_data.keys()
# Out:
# dict_keys(['x_train', 'x_test', 'y_train', 'y_test', 'y_t_train', 'y_t_test', 'maxlen', 'num_features', 'Inference_train', 'Inference_test', 'xy_train_firststate', 'xy_test_firststate'])

# %%
input_data["x_train"].shape
input_data["xy_train_firststate"].shape
# Out:
# (180, 3)

# %%
input_data["xy_train_firststate"]
# Out:
#        0  y_time_to_ev  y_closed
# 0    0.0     12.494925         1
# 1    0.0     12.138770         1
# 2    0.0     11.922515         1
# 3    0.0     10.377210         1
# 4    0.0     12.764252         1
# ..   ...           ...       ...
# 175  0.0     12.049921         1
# 176  0.0     11.635615         1
# 177  0.0     11.460185         1
# 178  0.0     10.694247         1
# 179  0.0     10.034796         1
#
# [180 rows x 3 columns]

# %%
#from sklearn.model

def training_function():
    print("training")
    return

#from sklearn.metrics 

def eval_function():
    print("evaluation")
    return

# %% [markdown]
# # Perform the experiments
# Here you want to bring your own code into the end of the simulation loop.

# %%
from SynBPS.simulation.simulation_pipeline import run_experiments
results = run_experiments(training_function, 
                          eval_function, 
                          out_file="data/results.csv", 
                          design_table="data/design_table.csv")
