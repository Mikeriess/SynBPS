# %% [markdown]
# # Testing modules

# %%
# install requirements
# !pip install numpy pandas scikit-learn matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in /Users/mikeriess/anaconda3/envs/sbps_testing/lib/python3.10/site-packages (2.0.0)
# Requirement already satisfied: pandas in /Users/mikeriess/anaconda3/envs/sbps_testing/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /Users/mikeriess/anaconda3/envs/sbps_testing/lib/python3.10/site-packages (1.5.1)
# Collecting matplotlib
#   Using cached matplotlib-3.9.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mikeriess/anaconda3/envs/sbps_testing/lib/python3.10/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mikeriess/anaconda3/envs/sbps_testing/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mikeriess/anaconda3/envs/sbps_testing/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in /Users/mikeriess/anaconda3/envs/sbps_testing/lib/python3.10/site-packages (from scikit-learn) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/mikeriess/anaconda3/envs/sbps_testing/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/mikeriess/anaconda3/envs/sbps_testing/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.53.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (162 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/mikeriess/anaconda3/envs/sbps_testing/lib/python3.10/site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-10.4.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: six>=1.5 in /Users/mikeriess/anaconda3/envs/sbps_testing/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached matplotlib-3.9.1-cp310-cp310-macosx_11_0_arm64.whl (7.8 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached contourpy-1.2.1-cp310-cp310-macosx_11_0_arm64.whl (244 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.53.1-cp310-cp310-macosx_11_0_arm64.whl (2.2 MB)
# Using cached kiwisolver-1.4.5-cp310-cp310-macosx_11_0_arm64.whl (66 kB)
# Using cached pillow-10.4.0-cp310-cp310-macosx_11_0_arm64.whl (3.4 MB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.1 pillow-10.4.0 pyparsing-3.1.2 seaborn-0.13.2

# %%
import sys
import os
sys.path.append(os.path.abspath('../src'))

# %%
# Suppress warnings in this notebook
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Make an experimental design table
# Here the settings for the experiments can be modified in the dictionary called run_settings. Refer to the paper for more details on of each of the parameters.

# %% [markdown]
# ## A less complicated example:

# %%
run_settings = {# level of entropy: min, medium and/or max
                "process_entropy":["min_entropy"], #,"med_entropy","max_entropy"
                
                # number of traces/cases in the event-log
                "number_of_traces":[500],

                # number of activity types
                "statespace_size":[5], 

                # first or higher-order markov chain to represent the transitions
                "process_type":["memoryless"], 
                
                # order of HOMC - only specify this when using process with memory
                "process_memory":[2],
                
                # number of transitions - only used for medium entropy (should be higher than 2 and < statespace size)
                "med_ent_n_transitions":[1,2,3,4,5],
                                
                # lambda parameter of inter-arrival times
                "inter_arrival_time":[1.5],
                
                # lambda parameter of process noise
                "process_stability_scale":[0.1],
                
                # probability of agent being available
                "resource_availability_p":[0.5],

                # number of agents in the process
                "resource_availability_n":[3],

                # waiting time in full days, when no agent is available
                "resource_availability_m":[0.041],
                
                # variation between activity durations
                "activity_duration_lambda_range":[1],
                
                # business hours definition: when can cases be processed? ()
                "Deterministic_offset_W":["weekdays"],

                # time-unit for a full week: days = 7, hrs = 24*7, etc.
                "Deterministic_offset_u":[7],
                
                # training data format (See Verenich et al., 2019): 
                # True - use first event to predict total cycle-time. 
                # False - use Prefix-log format / each event to predict remaining cycle time.
                "first_state_model":[False],

                # offset for the timestamps used (years after 1970)
                "datetime_offset":[45],
                
                # number of repetitions of the experiments: duplicates the experiment table (2 times here)
                "num_replications":list(range(0, 5))
               }


# import the make_design_table function to generate a full factorial experimental design table
from SynBPS.simulation.DoE import make_design_table
df = make_design_table(run_settings, file="data/design_table.csv")

# inspect the resulting design table
df
# Out:
# saved to data/design_table.csv
#    process_entropy  number_of_traces  statespace_size process_type  \
# 0      min_entropy             500.0                5   memoryless
# 1      min_entropy             500.0                5   memoryless
# 2      min_entropy             500.0                5   memoryless
# 3      min_entropy             500.0                5   memoryless
# 4      min_entropy             500.0                5   memoryless
# 5      min_entropy             500.0                5   memoryless
# 6      min_entropy             500.0                5   memoryless
# 7      min_entropy             500.0                5   memoryless
# 8      min_entropy             500.0                5   memoryless
# 9      min_entropy             500.0                5   memoryless
# 10     min_entropy             500.0                5   memoryless
# 11     min_entropy             500.0                5   memoryless
# 12     min_entropy             500.0                5   memoryless
# 13     min_entropy             500.0                5   memoryless
# 14     min_entropy             500.0                5   memoryless
# 15     min_entropy             500.0                5   memoryless
# 16     min_entropy             500.0                5   memoryless
# 17     min_entropy             500.0                5   memoryless
# 18     min_entropy             500.0                5   memoryless
# 19     min_entropy             500.0                5   memoryless
# 20     min_entropy             500.0                5   memoryless
# 21     min_entropy             500.0                5   memoryless
# 22     min_entropy             500.0                5   memoryless
# 23     min_entropy             500.0                5   memoryless
# 24     min_entropy             500.0                5   memoryless
#
#     process_memory  med_ent_n_transitions  inter_arrival_time  \
# 0              2.0                    1.0                 1.5
# 1              2.0                    2.0                 1.5
# 2              2.0                    3.0                 1.5
# 3              2.0                    4.0                 1.5
# 4              2.0                    5.0                 1.5
# 5              2.0                    1.0                 1.5
# 6              2.0                    2.0                 1.5
# 7              2.0                    3.0                 1.5
# 8              2.0                    4.0                 1.5
# 9              2.0                    5.0                 1.5
# 10             2.0                    1.0                 1.5
# 11             2.0                    2.0                 1.5
# 12             2.0                    3.0                 1.5
# 13             2.0                    4.0                 1.5
# 14             2.0                    5.0                 1.5
# 15             2.0                    1.0                 1.5
# 16             2.0                    2.0                 1.5
# 17             2.0                    3.0                 1.5
# 18             2.0                    4.0                 1.5
# 19             2.0                    5.0                 1.5
# 20             2.0                    1.0                 1.5
# 21             2.0                    2.0                 1.5
# 22             2.0                    3.0                 1.5
# 23             2.0                    4.0                 1.5
# 24             2.0                    5.0                 1.5
#
#     process_stability_scale  resource_availability_p  resource_availability_n  \
# 0                       0.1                      0.5                      3.0
# 1                       0.1                      0.5                      3.0
# 2                       0.1                      0.5                      3.0
# 3                       0.1                      0.5                      3.0
# 4                       0.1                      0.5                      3.0
# 5                       0.1                      0.5                      3.0
# 6                       0.1                      0.5                      3.0
# 7                       0.1                      0.5                      3.0
# 8                       0.1                      0.5                      3.0
# 9                       0.1                      0.5                      3.0
# 10                      0.1                      0.5                      3.0
# 11                      0.1                      0.5                      3.0
# 12                      0.1                      0.5                      3.0
# 13                      0.1                      0.5                      3.0
# 14                      0.1                      0.5                      3.0
# 15                      0.1                      0.5                      3.0
# 16                      0.1                      0.5                      3.0
# 17                      0.1                      0.5                      3.0
# 18                      0.1                      0.5                      3.0
# 19                      0.1                      0.5                      3.0
# 20                      0.1                      0.5                      3.0
# 21                      0.1                      0.5                      3.0
# 22                      0.1                      0.5                      3.0
# 23                      0.1                      0.5                      3.0
# 24                      0.1                      0.5                      3.0
#
#     resource_availability_m  activity_duration_lambda_range  \
# 0                     0.041                             1.0
# 1                     0.041                             1.0
# 2                     0.041                             1.0
# 3                     0.041                             1.0
# 4                     0.041                             1.0
# 5                     0.041                             1.0
# 6                     0.041                             1.0
# 7                     0.041                             1.0
# 8                     0.041                             1.0
# 9                     0.041                             1.0
# 10                    0.041                             1.0
# 11                    0.041                             1.0
# 12                    0.041                             1.0
# 13                    0.041                             1.0
# 14                    0.041                             1.0
# 15                    0.041                             1.0
# 16                    0.041                             1.0
# 17                    0.041                             1.0
# 18                    0.041                             1.0
# 19                    0.041                             1.0
# 20                    0.041                             1.0
# 21                    0.041                             1.0
# 22                    0.041                             1.0
# 23                    0.041                             1.0
# 24                    0.041                             1.0
#
#    Deterministic_offset_W  Deterministic_offset_u first_state_model  \
# 0                weekdays                     7.0             False
# 1                weekdays                     7.0             False
# 2                weekdays                     7.0             False
# 3                weekdays                     7.0             False
# 4                weekdays                     7.0             False
# 5                weekdays                     7.0             False
# 6                weekdays                     7.0             False
# 7                weekdays                     7.0             False
# 8                weekdays                     7.0             False
# 9                weekdays                     7.0             False
# 10               weekdays                     7.0             False
# 11               weekdays                     7.0             False
# 12               weekdays                     7.0             False
# 13               weekdays                     7.0             False
# 14               weekdays                     7.0             False
# 15               weekdays                     7.0             False
# 16               weekdays                     7.0             False
# 17               weekdays                     7.0             False
# 18               weekdays                     7.0             False
# 19               weekdays                     7.0             False
# 20               weekdays                     7.0             False
# 21               weekdays                     7.0             False
# 22               weekdays                     7.0             False
# 23               weekdays                     7.0             False
# 24               weekdays                     7.0             False
#
#     datetime_offset  num_replications  RUN  Done  Failure
# 0              45.0               0.0    1     0        0
# 1              45.0               0.0    2     0        0
# 2              45.0               0.0    3     0        0
# 3              45.0               0.0    4     0        0
# 4              45.0               0.0    5     0        0
# 5              45.0               1.0    6     0        0
# 6              45.0               1.0    7     0        0
# 7              45.0               1.0    8     0        0
# 8              45.0               1.0    9     0        0
# 9              45.0               1.0   10     0        0
# 10             45.0               2.0   11     0        0
# 11             45.0               2.0   12     0        0
# 12             45.0               2.0   13     0        0
# 13             45.0               2.0   14     0        0
# 14             45.0               2.0   15     0        0
# 15             45.0               3.0   16     0        0
# 16             45.0               3.0   17     0        0
# 17             45.0               3.0   18     0        0
# 18             45.0               3.0   19     0        0
# 19             45.0               3.0   20     0        0
# 20             45.0               4.0   21     0        0
# 21             45.0               4.0   22     0        0
# 22             45.0               4.0   23     0        0
# 23             45.0               4.0   24     0        0
# 24             45.0               4.0   25     0        0

# %% [markdown]
# # Specify Train() and Test() functions
# Before running the experiments, you need to define model training and evaluation functions.
#
# In this example we train a first state model, which is a model using only the first observed event (state) to predict to total cycle-time. The default data preparation will result in a prefix-log, which can be used to predict remaining cycle-time from every observed event in the trace.
#
# Input for the **training_function** is a dictionary named **input_data**, which contain the following:
# - x_train
# - x_test
# - y_train
# - y_test
#
# Output is an **inference table** containing predictions and actual target values for the test data. This table is used for analysis of the results. The **eval_function** also uses this table to calculate aggregated metrics.

# %%
def training_function(input_data):
    print("training")
    
    """
    Example model: Lasso regression
    This is just an example of how to define your model in this framework.
    Using this model on this data format is not advised as we break i.i.d. assumptions.
    """

    #retrieve model class from sklearn
    from sklearn import linear_model


    # Lasso model
    #reg = linear_model.Lasso(alpha=0.1)
    # OLS
    reg = linear_model.LinearRegression()

    #reshape training data for this type of model 
    #(from: N x t x k, to: N x (t x k))
    #num_obs = input_data["x_train"].shape[0]
    from numpy import prod
    flattened_dim = prod(input_data["x_train"].shape[1:])

    #train the regression model
    reg.fit(input_data["x_train"].reshape((input_data["x_train"].shape[0], flattened_dim)), input_data["y_train"])

    #predict on the test data
    y_pred = reg.predict(input_data["x_test"].reshape((input_data["x_test"].shape[0], flattened_dim)))

    #get the inference table (used for analysis of the final results)
    inference = input_data["Inference_test"]
    
    #add predictions to the inference table
    inference["y_pred"] = y_pred
    return inference

#from sklearn.metrics 

def eval_function(inference):
    print("evaluation")
    """
    Example evaluation: Aggregated scores
    The inference table also enable the ability to make trace or prefix-level evaluations using its id variables
    """
    from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score

    y = inference["y"]
    y_pred = inference["y_pred"]

    MSE = mean_squared_error(y, y_pred)
    MAE = mean_absolute_error(y, y_pred)
    R2 = r2_score(y, y_pred)
    EVAR = explained_variance_score(y, y_pred)

    # the resulting metrics should be stored in a dictionary and be scalars only
    # adding prefixes to column name (key) is suggested when logging many metrics
    metrics = {"TEST_MSE":MSE,
              "TEST_MAE":MAE,
              "TEST_R2":R2,
              "TEST_EVAR":EVAR}
    print(metrics)
    return metrics

# %% [markdown]
# # Perform the experiments
# Now we perform the experiments using the defined training and evaluation functions.

# %%
from SynBPS.simulation.simulation_pipeline import run_experiments
results = run_experiments(training_function, 
                          eval_function, 
                          output_dir="data/",
                          out_file="results.csv", 
                          design_table="design_table.csv")
# Out:
# Run: 0
# traces: 500
# eventlog saved to: data/0_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 06:41:06
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     d            1  2015-01-02 06:41:06 2015-01-02 12:37:48
# 1   1     c            2  2015-01-03 06:00:00 2015-01-03 22:57:40
# 2   1     e            3  2015-01-04 06:51:02 2015-01-04 08:01:35
# 3   1     f            4  2015-01-04 14:21:18 2015-01-04 16:53:14
# 4   1     b            5  2015-01-05 06:00:00 2015-01-05 20:43:15
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 06:41:06
# Last event starts at: 2017-02-11 17:21:55
# Train-test split happens at: 2016-01-23 06:41:06
# =======================================
# 500
# 500
# 1295
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1044
# Testset size (with prefixes of  5 ): 956
# ==========================================
# X: observations, timesteps, vars
# (1044, 5, 11)
# y_train: observations, labels
# (1044, 1)
# y_t_train: observations, labels
# (1044, 1)
# y_a_train: observations, labels
# (1044, 4)
# Inference train: 1044
# Inference test:  956
# training
# evaluation
# {'TEST_MSE': np.float64(12265267611.597971), 'TEST_MAE': np.float64(83841.87683782617), 'TEST_R2': 0.44906454415865826, 'TEST_EVAR': 0.4526347159171279}
# Run: 1
# traces: 500
# eventlog saved to: data/1_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-05 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     e            1  2015-01-05 06:00:00 2015-01-05 10:58:45
# 1   1     d            2  2015-01-05 12:21:05 2015-01-05 13:21:52
# 2   1     c            3  2015-01-06 06:00:00 2015-01-06 20:14:07
# 3   1     f            4  2015-01-09 06:00:00 2015-01-12 18:23:59
# 4   1     b            5  2015-01-13 06:00:00 2015-01-13 21:14:57
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-05 06:00:00
# Last event starts at: 2017-02-15 06:00:00
# Train-test split happens at: 2016-01-26 06:00:00
# =======================================
# 500
# 500
# 1230
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 988
# Testset size (with prefixes of  5 ): 1012
# ==========================================
# X: observations, timesteps, vars
# (988, 5, 11)
# y_train: observations, labels
# (988, 1)
# y_t_train: observations, labels
# (988, 1)
# y_a_train: observations, labels
# (988, 4)
# Inference train: 988
# Inference test:  1012
# training
# evaluation
# {'TEST_MSE': np.float64(19198924383.07024), 'TEST_MAE': np.float64(106979.0591031607), 'TEST_R2': 0.40806616325013023, 'TEST_EVAR': 0.40811397593391907}
# Run: 2
# traces: 500
# eventlog saved to: data/2_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 07:00:21
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     f            1  2015-01-02 07:00:21 2015-01-04 11:39:40
# 1   1     b            2  2015-01-04 14:11:04 2015-01-04 14:17:03
# 2   1     c            3  2015-01-05 06:00:00 2015-01-05 09:57:22
# 3   1     d            4  2015-01-05 14:14:11 2015-01-06 03:30:37
# 4   1     e            5  2015-01-06 07:33:21 2015-01-08 00:29:16
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 07:00:21
# Last event starts at: 2017-01-03 13:50:22
# Train-test split happens at: 2016-01-03 07:00:21
# =======================================
# 500
# 500
# 1271
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1024
# Testset size (with prefixes of  5 ): 976
# ==========================================
# X: observations, timesteps, vars
# (1024, 5, 11)
# y_train: observations, labels
# (1024, 1)
# y_t_train: observations, labels
# (1024, 1)
# y_a_train: observations, labels
# (1024, 4)
# Inference train: 1024
# Inference test:  976
# training
# evaluation
# {'TEST_MSE': np.float64(10265528108.581802), 'TEST_MAE': np.float64(79802.91962934713), 'TEST_R2': 0.4147307467329281, 'TEST_EVAR': 0.42056205298612426}
# Run: 3
# traces: 500
# eventlog saved to: data/3_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 15:40:57
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     b            1  2015-01-02 15:40:57 2015-01-02 17:06:22
# 1   1     e            2  2015-01-03 06:00:00 2015-01-03 12:37:08
# 2   1     d            3  2015-01-03 17:49:08 2015-01-06 12:18:51
# 3   1     c            4  2015-01-06 16:56:12 2015-01-06 17:02:19
# 4   1     f            5  2015-01-09 06:00:00 2015-01-10 01:46:46
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 15:40:57
# Last event starts at: 2016-12-21 12:37:26
# Train-test split happens at: 2015-12-28 15:40:57
# =======================================
# 500
# 500
# 1320
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1064
# Testset size (with prefixes of  5 ): 936
# ==========================================
# X: observations, timesteps, vars
# (1064, 5, 11)
# y_train: observations, labels
# (1064, 1)
# y_t_train: observations, labels
# (1064, 1)
# y_a_train: observations, labels
# (1064, 4)
# Inference train: 1064
# Inference test:  936
# training
# evaluation
# {'TEST_MSE': np.float64(14079942824.130547), 'TEST_MAE': np.float64(86763.54450752388), 'TEST_R2': 0.4942755219520786, 'TEST_EVAR': 0.4960346595547489}
# Run: 4
# traces: 500
# eventlog saved to: data/4_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-03 07:19:22
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     f            1  2015-01-03 07:19:22 2015-01-03 11:03:06
# 1   1     b            2  2015-01-03 12:03:05 2015-01-04 01:08:46
# 2   1     d            3  2015-01-04 06:00:00 2015-01-04 18:18:25
# 3   1     c            4  2015-01-05 06:00:00 2015-01-05 17:12:56
# 4   1     e            5  2015-01-06 06:00:00 2015-01-06 07:29:13
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-03 07:19:22
# Last event starts at: 2017-01-11 17:54:14
# Train-test split happens at: 2016-01-08 07:19:22
# =======================================
# 500
# 500
# 1155
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 928
# Testset size (with prefixes of  5 ): 1072
# ==========================================
# X: observations, timesteps, vars
# (928, 5, 11)
# y_train: observations, labels
# (928, 1)
# y_t_train: observations, labels
# (928, 1)
# y_a_train: observations, labels
# (928, 4)
# Inference train: 928
# Inference test:  1072
# training
# evaluation
# {'TEST_MSE': np.float64(21596940116.35119), 'TEST_MAE': np.float64(107943.94851296162), 'TEST_R2': 0.38397332658940353, 'TEST_EVAR': 0.3840857862443168}
# Run: 5
# traces: 500
# eventlog saved to: data/5_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 08:14:31
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     d            1  2015-01-02 08:14:31 2015-01-02 10:28:06
# 1   1     f            2  2015-01-02 13:44:48 2015-01-02 18:51:08
# 2   1     c            3  2015-01-03 06:00:00 2015-01-04 19:56:18
# 3   1     b            4  2015-01-05 06:00:00 2015-01-05 06:13:29
# 4   1     e            5  2015-01-05 13:41:09 2015-01-06 01:50:52
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 08:14:31
# Last event starts at: 2016-12-19 06:00:00
# Train-test split happens at: 2015-12-26 08:14:31
# =======================================
# 500
# 500
# 1281
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1028
# Testset size (with prefixes of  5 ): 972
# ==========================================
# X: observations, timesteps, vars
# (1028, 5, 11)
# y_train: observations, labels
# (1028, 1)
# y_t_train: observations, labels
# (1028, 1)
# y_a_train: observations, labels
# (1028, 4)
# Inference train: 1028
# Inference test:  972
# training
# evaluation
# {'TEST_MSE': np.float64(6228300209.681585), 'TEST_MAE': np.float64(61128.74826106558), 'TEST_R2': 0.5324793576779085, 'TEST_EVAR': 0.5326649202728982}
# Run: 6
# traces: 500
# eventlog saved to: data/6_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 13:38:36
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     f            1  2015-01-02 13:38:36 2015-01-02 15:03:31
# 1   1     c            2  2015-01-03 06:00:00 2015-01-03 07:44:17
# 2   1     b            3  2015-01-03 17:43:32 2015-01-03 21:26:53
# 3   1     e            4  2015-01-04 08:51:43 2015-01-04 17:13:55
# 4   1     d            5  2015-01-05 06:00:00 2015-01-05 06:51:34
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 08:24:39
# Last event starts at: 2016-12-26 06:00:00
# Train-test split happens at: 2015-12-30 08:24:39
# =======================================
# 500
# 500
# 1254
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1004
# Testset size (with prefixes of  5 ): 996
# ==========================================
# X: observations, timesteps, vars
# (1004, 5, 11)
# y_train: observations, labels
# (1004, 1)
# y_t_train: observations, labels
# (1004, 1)
# y_a_train: observations, labels
# (1004, 4)
# Inference train: 1004
# Inference test:  996
# training
# evaluation
# {'TEST_MSE': np.float64(15444643535.440329), 'TEST_MAE': np.float64(97845.73428762246), 'TEST_R2': 0.3710273077612215, 'TEST_EVAR': 0.3731804934007772}
# Run: 7
# traces: 500
# eventlog saved to: data/7_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-09 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     b            1  2015-01-09 06:00:00 2015-01-12 17:01:17
# 1   1     f            2  2015-01-13 06:00:00 2015-01-13 10:21:42
# 2   1     d            3  2015-01-13 17:16:32 2015-01-13 19:17:14
# 3   1     e            4  2015-01-16 06:00:00 2015-01-17 07:55:37
# 4   1     c            5  2015-01-17 10:40:07 2015-01-17 13:51:32
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-09 06:00:00
# Last event starts at: 2017-02-21 17:47:04
# Train-test split happens at: 2016-02-01 06:00:00
# =======================================
# 500
# 500
# 1239
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1000
# Testset size (with prefixes of  5 ): 1000
# ==========================================
# X: observations, timesteps, vars
# (1000, 5, 11)
# y_train: observations, labels
# (1000, 1)
# y_t_train: observations, labels
# (1000, 1)
# y_a_train: observations, labels
# (1000, 4)
# Inference train: 1000
# Inference test:  1000
# training
# evaluation
# {'TEST_MSE': np.float64(11171567515.716913), 'TEST_MAE': np.float64(81614.09562519605), 'TEST_R2': 0.5350849649468481, 'TEST_EVAR': 0.5353419249823267}
# Run: 8
# traces: 500
# eventlog saved to: data/8_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-03 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     d            1  2015-01-03 06:00:00 2015-01-05 06:56:06
# 1   1     c            2  2015-01-05 10:45:28 2015-01-06 09:07:14
# 2   1     b            3  2015-01-06 11:41:41 2015-01-07 01:22:06
# 3   1     f            4  2015-01-09 06:00:00 2015-01-09 08:38:28
# 4   1     e            5  2015-01-09 13:44:45 2015-01-09 19:23:38
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-03 06:00:00
# Last event starts at: 2016-12-26 06:00:00
# Train-test split happens at: 2015-12-31 06:00:00
# =======================================
# 500
# 500
# 1252
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1004
# Testset size (with prefixes of  5 ): 996
# ==========================================
# X: observations, timesteps, vars
# (1004, 5, 11)
# y_train: observations, labels
# (1004, 1)
# y_t_train: observations, labels
# (1004, 1)
# y_a_train: observations, labels
# (1004, 4)
# Inference train: 1004
# Inference test:  996
# training
# evaluation
# {'TEST_MSE': np.float64(15858725035.04964), 'TEST_MAE': np.float64(100434.11735281983), 'TEST_R2': 0.49997980055386537, 'TEST_EVAR': 0.5015020927178441}
# Run: 9
# traces: 500
# eventlog saved to: data/9_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-06 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     b            1  2015-01-06 06:00:00 2015-01-06 07:39:20
# 1   1     e            2  2015-01-06 16:05:51 2015-01-06 22:21:44
# 2   1     c            3  2015-01-09 06:00:00 2015-01-09 06:08:58
# 3   1     d            4  2015-01-09 07:08:49 2015-01-09 15:58:56
# 4   1     f            5  2015-01-10 06:00:00 2015-01-10 06:17:50
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-06 06:00:00
# Last event starts at: 2017-02-25 06:00:00
# Train-test split happens at: 2016-02-01 06:00:00
# =======================================
# 500
# 500
# 1176
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 944
# Testset size (with prefixes of  5 ): 1056
# ==========================================
# X: observations, timesteps, vars
# (944, 5, 11)
# y_train: observations, labels
# (944, 1)
# y_t_train: observations, labels
# (944, 1)
# y_a_train: observations, labels
# (944, 4)
# Inference train: 944
# Inference test:  1056
# training
# evaluation
# {'TEST_MSE': np.float64(16977534984.710602), 'TEST_MAE': np.float64(99241.49309324179), 'TEST_R2': 0.33549025131830934, 'TEST_EVAR': 0.3393897858515996}
# Run: 10
# traces: 500
# eventlog saved to: data/10_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 12:48:35
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     d            1  2015-01-02 12:48:35 2015-01-02 12:48:53
# 1   1     c            2  2015-01-02 16:52:39 2015-01-03 12:55:18
# 2   1     e            3  2015-01-03 16:27:10 2015-01-03 17:47:42
# 3   1     f            4  2015-01-04 06:00:00 2015-01-04 07:43:59
# 4   1     b            5  2015-01-04 09:13:05 2015-01-04 18:12:46
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 12:48:35
# Last event starts at: 2017-02-06 14:58:55
# Train-test split happens at: 2016-01-21 12:48:35
# =======================================
# 500
# 500
# 1243
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1000
# Testset size (with prefixes of  5 ): 1000
# ==========================================
# X: observations, timesteps, vars
# (1000, 5, 11)
# y_train: observations, labels
# (1000, 1)
# y_t_train: observations, labels
# (1000, 1)
# y_a_train: observations, labels
# (1000, 4)
# Inference train: 1000
# Inference test:  1000
# training
# evaluation
# {'TEST_MSE': np.float64(14382032106.752483), 'TEST_MAE': np.float64(90348.67852757644), 'TEST_R2': 0.31426217124040257, 'TEST_EVAR': 0.3213718744137841}
# Run: 11
# traces: 500
# eventlog saved to: data/11_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-03 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     c            1  2015-01-03 06:00:00 2015-01-03 08:16:41
# 1   1     b            2  2015-01-03 10:13:41 2015-01-03 17:53:12
# 2   1     e            3  2015-01-04 06:00:00 2015-01-04 08:25:51
# 3   1     d            4  2015-01-04 10:42:57 2015-01-05 13:52:11
# 4   1     f            5  2015-01-05 16:33:34 2015-01-06 02:45:01
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-03 06:00:00
# Last event starts at: 2016-11-15 15:56:18
# Train-test split happens at: 2015-12-11 06:00:00
# =======================================
# 500
# 500
# 1298
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1044
# Testset size (with prefixes of  5 ): 956
# ==========================================
# X: observations, timesteps, vars
# (1044, 5, 11)
# y_train: observations, labels
# (1044, 1)
# y_t_train: observations, labels
# (1044, 1)
# y_a_train: observations, labels
# (1044, 4)
# Inference train: 1044
# Inference test:  956
# training
# evaluation
# {'TEST_MSE': np.float64(11915059579.11291), 'TEST_MAE': np.float64(87179.40344711527), 'TEST_R2': 0.2665233305171619, 'TEST_EVAR': 0.2670167107114152}
# Run: 12
# traces: 500
# eventlog saved to: data/12_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     c            1  2015-01-02 06:00:00 2015-01-03 06:30:01
# 1   1     d            2  2015-01-03 12:08:49 2015-01-03 21:56:27
# 2   1     b            3  2015-01-04 06:00:00 2015-01-04 06:39:55
# 3   1     f            4  2015-01-04 12:44:42 2015-01-04 16:45:21
# 4   1     e            5  2015-01-05 06:00:00 2015-01-06 01:08:45
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 06:00:00
# Last event starts at: 2017-01-30 15:07:26
# Train-test split happens at: 2016-01-17 06:00:00
# =======================================
# 500
# 500
# 1253
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1008
# Testset size (with prefixes of  5 ): 992
# ==========================================
# X: observations, timesteps, vars
# (1008, 5, 11)
# y_train: observations, labels
# (1008, 1)
# y_t_train: observations, labels
# (1008, 1)
# y_a_train: observations, labels
# (1008, 4)
# Inference train: 1008
# Inference test:  992
# training
# evaluation
# {'TEST_MSE': np.float64(10516895035.129696), 'TEST_MAE': np.float64(77169.99278988545), 'TEST_R2': 0.5162041180488794, 'TEST_EVAR': 0.516262700805259}
# Run: 13
# traces: 500
# eventlog saved to: data/13_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-03 14:20:40
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     c            1  2015-01-03 14:20:40 2015-01-03 17:58:38
# 1   1     b            2  2015-01-04 06:00:00 2015-01-04 08:23:45
# 2   1     f            3  2015-01-04 11:52:28 2015-01-04 16:19:48
# 3   1     e            4  2015-01-05 06:00:00 2015-01-05 07:21:13
# 4   1     d            5  2015-01-05 10:50:47 2015-01-06 02:10:19
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-03 13:50:57
# Last event starts at: 2017-01-22 06:15:31
# Train-test split happens at: 2016-01-13 13:50:57
# =======================================
# 500
# 500
# 1279
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1028
# Testset size (with prefixes of  5 ): 972
# ==========================================
# X: observations, timesteps, vars
# (1028, 5, 11)
# y_train: observations, labels
# (1028, 1)
# y_t_train: observations, labels
# (1028, 1)
# y_a_train: observations, labels
# (1028, 4)
# Inference train: 1028
# Inference test:  972
# training
# evaluation
# {'TEST_MSE': np.float64(17979801986.426334), 'TEST_MAE': np.float64(98859.31100970347), 'TEST_R2': 0.3180645648832301, 'TEST_EVAR': 0.31810138912121433}
# Run: 14
# traces: 500
# eventlog saved to: data/14_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-03 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     f            1  2015-01-03 06:00:00 2015-01-03 07:51:02
# 1   1     e            2  2015-01-03 10:32:18 2015-01-03 14:43:30
# 2   1     b            3  2015-01-04 06:00:00 2015-01-04 06:16:50
# 3   1     d            4  2015-01-04 07:41:05 2015-01-04 12:09:51
# 4   1     c            5  2015-01-04 14:50:58 2015-01-05 09:31:00
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-03 06:00:00
# Last event starts at: 2017-02-18 13:42:51
# Train-test split happens at: 2016-01-27 06:00:00
# =======================================
# 500
# 500
# 1250
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1004
# Testset size (with prefixes of  5 ): 996
# ==========================================
# X: observations, timesteps, vars
# (1004, 5, 11)
# y_train: observations, labels
# (1004, 1)
# y_t_train: observations, labels
# (1004, 1)
# y_a_train: observations, labels
# (1004, 4)
# Inference train: 1004
# Inference test:  996
# training
# evaluation
# {'TEST_MSE': np.float64(9070599589.667124), 'TEST_MAE': np.float64(73197.85512375066), 'TEST_R2': 0.3098340469268174, 'TEST_EVAR': 0.31596502886027156}
# Run: 15
# traces: 500
# eventlog saved to: data/15_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-03 06:29:58
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     d            1  2015-01-03 06:29:58 2015-01-03 10:53:58
# 1   1     e            2  2015-01-04 06:00:00 2015-01-04 09:46:06
# 2   1     f            3  2015-01-04 13:31:56 2015-01-04 16:04:07
# 3   1     c            4  2015-01-05 06:00:00 2015-01-05 07:30:33
# 4   1     b            5  2015-01-05 10:32:02 2015-01-05 12:10:51
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-03 06:29:58
# Last event starts at: 2017-02-15 14:54:24
# Train-test split happens at: 2016-01-26 06:29:58
# =======================================
# 500
# 500
# 1306
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1048
# Testset size (with prefixes of  5 ): 952
# ==========================================
# X: observations, timesteps, vars
# (1048, 5, 11)
# y_train: observations, labels
# (1048, 1)
# y_t_train: observations, labels
# (1048, 1)
# y_a_train: observations, labels
# (1048, 4)
# Inference train: 1048
# Inference test:  952
# training
# evaluation
# {'TEST_MSE': np.float64(8321242661.698709), 'TEST_MAE': np.float64(68993.46349153249), 'TEST_R2': 0.5539211569999584, 'TEST_EVAR': 0.55399839971062}
# Run: 16
# traces: 500
# eventlog saved to: data/16_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-04 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     e            1  2015-01-04 06:00:00 2015-01-04 08:39:16
# 1   1     c            2  2015-01-04 12:40:14 2015-01-04 17:27:21
# 2   1     f            3  2015-01-05 06:00:00 2015-01-05 06:47:13
# 3   1     d            4  2015-01-05 10:29:03 2015-01-05 13:11:08
# 4   1     b            5  2015-01-06 06:00:00 2015-01-06 11:29:58
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-04 06:00:00
# Last event starts at: 2017-04-14 14:55:23
# Train-test split happens at: 2016-02-24 06:00:00
# =======================================
# 500
# 500
# 1340
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1072
# Testset size (with prefixes of  5 ): 928
# ==========================================
# X: observations, timesteps, vars
# (1072, 5, 11)
# y_train: observations, labels
# (1072, 1)
# y_t_train: observations, labels
# (1072, 1)
# y_a_train: observations, labels
# (1072, 4)
# Inference train: 1072
# Inference test:  928
# training
# evaluation
# {'TEST_MSE': np.float64(13462621678.104109), 'TEST_MAE': np.float64(84432.98842373618), 'TEST_R2': 0.43981162443643973, 'TEST_EVAR': 0.4424180725633786}
# Run: 17
# traces: 500
# eventlog saved to: data/17_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     d            1  2015-01-02 06:00:00 2015-01-02 08:41:09
# 1   1     c            2  2015-01-02 13:03:22 2015-01-02 16:45:53
# 2   1     f            3  2015-01-03 06:00:00 2015-01-03 16:17:32
# 3   1     e            4  2015-01-04 06:00:00 2015-01-04 06:24:52
# 4   1     b            5  2015-01-04 15:25:59 2015-01-06 03:50:52
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 06:00:00
# Last event starts at: 2017-02-25 06:00:00
# Train-test split happens at: 2016-01-30 06:00:00
# =======================================
# 500
# 500
# 1241
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1000
# Testset size (with prefixes of  5 ): 1000
# ==========================================
# X: observations, timesteps, vars
# (1000, 5, 11)
# y_train: observations, labels
# (1000, 1)
# y_t_train: observations, labels
# (1000, 1)
# y_a_train: observations, labels
# (1000, 4)
# Inference train: 1000
# Inference test:  1000
# training
# evaluation
# {'TEST_MSE': np.float64(13507267666.883823), 'TEST_MAE': np.float64(88793.1828790245), 'TEST_R2': 0.28640950080742866, 'TEST_EVAR': 0.2870264791232445}
# Run: 18
# traces: 500
# eventlog saved to: data/18_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     f            1  2015-01-02 06:00:00 2015-01-02 12:21:41
# 1   1     b            2  2015-01-03 06:00:00 2015-01-04 01:08:33
# 2   1     e            3  2015-01-04 06:00:00 2015-01-05 01:15:20
# 3   1     d            4  2015-01-05 15:50:26 2015-01-05 16:20:00
# 4   1     c            5  2015-01-06 06:00:00 2015-01-07 22:43:50
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 06:00:00
# Last event starts at: 2017-03-28 06:00:00
# Train-test split happens at: 2016-02-14 06:00:00
# =======================================
# 500
# 500
# 1231
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1008
# Testset size (with prefixes of  5 ): 992
# ==========================================
# X: observations, timesteps, vars
# (1008, 5, 11)
# y_train: observations, labels
# (1008, 1)
# y_t_train: observations, labels
# (1008, 1)
# y_a_train: observations, labels
# (1008, 4)
# Inference train: 1008
# Inference test:  992
# training
# evaluation
# {'TEST_MSE': np.float64(10604947709.082054), 'TEST_MAE': np.float64(74187.06694424344), 'TEST_R2': 0.5756434840750254, 'TEST_EVAR': 0.5765759007468627}
# Run: 19
# traces: 500
# eventlog saved to: data/19_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 08:20:29
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     f            1  2015-01-02 08:20:29 2015-01-03 00:39:50
# 1   1     c            2  2015-01-03 06:00:00 2015-01-04 03:26:12
# 2   1     d            3  2015-01-04 06:16:42 2015-01-04 17:18:02
# 3   1     b            4  2015-01-05 06:00:00 2015-01-05 09:21:11
# 4   1     e            5  2015-01-05 12:34:33 2015-01-05 20:29:57
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 08:20:29
# Last event starts at: 2017-01-22 06:00:00
# Train-test split happens at: 2016-01-13 08:20:29
# =======================================
# 500
# 500
# 1256
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1008
# Testset size (with prefixes of  5 ): 992
# ==========================================
# X: observations, timesteps, vars
# (1008, 5, 11)
# y_train: observations, labels
# (1008, 1)
# y_t_train: observations, labels
# (1008, 1)
# y_a_train: observations, labels
# (1008, 4)
# Inference train: 1008
# Inference test:  992
# training
# evaluation
# {'TEST_MSE': np.float64(13309607735.06457), 'TEST_MAE': np.float64(89890.13146332435), 'TEST_R2': 0.4702116347260863, 'TEST_EVAR': 0.4708286200637458}
# Run: 20
# traces: 500
# eventlog saved to: data/20_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-04 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     d            1  2015-01-04 06:00:00 2015-01-04 18:53:31
# 1   1     b            2  2015-01-05 06:00:00 2015-01-05 06:08:31
# 2   1     f            3  2015-01-05 09:04:49 2015-01-06 13:21:15
# 3   1     e            4  2015-01-09 06:00:00 2015-01-10 07:08:54
# 4   1     c            5  2015-01-10 09:02:19 2015-01-10 14:53:53
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-04 06:00:00
# Last event starts at: 2016-11-28 12:00:35
# Train-test split happens at: 2015-12-18 06:00:00
# =======================================
# 500
# 500
# 1160
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 928
# Testset size (with prefixes of  5 ): 1072
# ==========================================
# X: observations, timesteps, vars
# (928, 5, 11)
# y_train: observations, labels
# (928, 1)
# y_t_train: observations, labels
# (928, 1)
# y_a_train: observations, labels
# (928, 4)
# Inference train: 928
# Inference test:  1072
# training
# evaluation
# {'TEST_MSE': np.float64(14528129970.145218), 'TEST_MAE': np.float64(89587.80900288218), 'TEST_R2': 0.4363350185262711, 'TEST_EVAR': 0.4368980156647948}
# Run: 21
# traces: 500
# eventlog saved to: data/21_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-04 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     b            1  2015-01-04 06:00:00 2015-01-04 06:50:58
# 1   1     d            2  2015-01-04 09:35:26 2015-01-04 13:02:37
# 2   1     f            3  2015-01-04 16:51:30 2015-01-06 14:02:26
# 3   1     c            4  2015-01-06 17:24:27 2015-01-06 20:03:28
# 4   1     e            5  2015-01-09 06:00:00 2015-01-10 08:19:46
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-04 06:00:00
# Last event starts at: 2017-02-13 16:35:53
# Train-test split happens at: 2016-01-25 06:00:00
# =======================================
# 500
# 500
# 1195
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 956
# Testset size (with prefixes of  5 ): 1044
# ==========================================
# X: observations, timesteps, vars
# (956, 5, 11)
# y_train: observations, labels
# (956, 1)
# y_t_train: observations, labels
# (956, 1)
# y_a_train: observations, labels
# (956, 4)
# Inference train: 956
# Inference test:  1044
# training
# evaluation
# {'TEST_MSE': np.float64(12618763263.657703), 'TEST_MAE': np.float64(84681.30485376454), 'TEST_R2': 0.35032161931227657, 'TEST_EVAR': 0.35262502190186584}
# Run: 22
# traces: 500
# eventlog saved to: data/22_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-05 06:00:00
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     f            1  2015-01-05 06:00:00 2015-01-05 06:00:23
# 1   1     e            2  2015-01-05 09:33:58 2015-01-05 19:33:05
# 2   1     c            3  2015-01-06 06:00:00 2015-01-07 07:12:28
# 3   1     d            4  2015-01-09 06:00:00 2015-01-09 07:00:07
# 4   1     b            5  2015-01-09 09:11:09 2015-01-09 13:22:14
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-05 06:00:00
# Last event starts at: 2016-11-15 09:18:16
# Train-test split happens at: 2015-12-11 06:00:00
# =======================================
# 500
# 500
# 1234
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 988
# Testset size (with prefixes of  5 ): 1012
# ==========================================
# X: observations, timesteps, vars
# (988, 5, 11)
# y_train: observations, labels
# (988, 1)
# y_t_train: observations, labels
# (988, 1)
# y_a_train: observations, labels
# (988, 4)
# Inference train: 988
# Inference test:  1012
# training
# evaluation
# {'TEST_MSE': np.float64(6305582865.336626), 'TEST_MAE': np.float64(62697.52010096086), 'TEST_R2': 0.4622179125630006, 'TEST_EVAR': 0.463891649114459}
# Run: 23
# traces: 500
# eventlog saved to: data/23_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-04 11:14:33
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     d            1  2015-01-04 11:14:33 2015-01-04 13:41:38
# 1   1     e            2  2015-01-05 06:00:00 2015-01-06 14:38:00
# 2   1     c            3  2015-01-06 16:42:07 2015-01-06 18:39:25
# 3   1     b            4  2015-01-09 06:00:00 2015-01-09 06:08:55
# 4   1     f            5  2015-01-09 08:20:22 2015-01-09 23:34:11
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-04 11:14:33
# Last event starts at: 2017-01-23 14:13:29
# Train-test split happens at: 2016-01-15 11:14:33
# =======================================
# 500
# 500
# 1278
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 1028
# Testset size (with prefixes of  5 ): 972
# ==========================================
# X: observations, timesteps, vars
# (1028, 5, 11)
# y_train: observations, labels
# (1028, 1)
# y_t_train: observations, labels
# (1028, 1)
# y_a_train: observations, labels
# (1028, 4)
# Inference train: 1028
# Inference test:  972
# training
# evaluation
# {'TEST_MSE': np.float64(9491228311.621033), 'TEST_MAE': np.float64(77915.72959189856), 'TEST_R2': 0.3640194982655771, 'TEST_EVAR': 0.36791328364199083}
# Run: 24
# traces: 500
# eventlog saved to: data/24_Eventlog_min_entropy_memoryless.csv
# events: 2500
# ids: 500
# Cases before dropping len=1: 500 cases 2500 rows
# Cases after dropping len=1: 500 cases 2500 rows
# Sorting by id, date (chronological order)
# Number of cases in log: 500
# longest trace is: 5
# Time format: 2015-01-02 17:57:31
# Std. format: %Y-%m-%d %H:%M:%S
#    id event  activity_no                 time        end_datetime
# 0   1     b            1  2015-01-02 17:57:31 2015-01-03 08:49:55
# 1   1     c            2  2015-01-03 10:07:54 2015-01-03 10:33:06
# 2   1     d            3  2015-01-03 13:48:45 2015-01-04 11:24:13
# 3   1     f            4  2015-01-04 16:03:01 2015-01-04 23:45:50
# 4   1     e            5  2015-01-05 06:00:00 2015-01-06 02:21:34
# mode: event
# =======================================
# =======================================
# Log starts at: 2015-01-02 17:57:31
# Last event starts at: 2017-03-10 06:00:00
# Train-test split happens at: 2016-02-05 17:57:31
# =======================================
# 500
# 500
# 1212
# =======================================
# ============================
# Post-processing:
# ============================
#
# dropping last event from each case
# before: 2500
# after: 2000
# data in X is the 5 last events, excluding the final event
#
# dropping vars:
# dropping last event category from y_a: ['y_a_t1_1']
# dropping vars from X:  ['y_timetofinish', 'y_timetonextev', 'next_activity', 'y_a_t1_1', 'y_a_t1_2', 'y_a_t1_3', 'y_a_t1_4', 'y_a_t1_5']
#
#
# Output length: 10000
# Generating case data
# done
# Making casestats..
# Done.
# reshaping..
# Trainset size (with prefixes of  5 ): 972
# Testset size (with prefixes of  5 ): 1028
# ==========================================
# X: observations, timesteps, vars
# (972, 5, 11)
# y_train: observations, labels
# (972, 1)
# y_t_train: observations, labels
# (972, 1)
# y_a_train: observations, labels
# (972, 4)
# Inference train: 972
# Inference test:  1028
# training
# evaluation
# {'TEST_MSE': np.float64(33306075339104.64), 'TEST_MAE': np.float64(393969.90183115343), 'TEST_R2': -1223.7351784185732, 'TEST_EVAR': -1223.729221376127}

# %% [markdown]
# # Analysis
# Work in progress..

# %%
import pandas as pd
df = pd.read_csv("data/results.csv")
df
# Out:
#    process_entropy  number_of_traces  statespace_size process_type  \
# 0      min_entropy             500.0                5   memoryless
# 1      min_entropy             500.0                5   memoryless
# 2      min_entropy             500.0                5   memoryless
# 3      min_entropy             500.0                5   memoryless
# 4      min_entropy             500.0                5   memoryless
# 5      min_entropy             500.0                5   memoryless
# 6      min_entropy             500.0                5   memoryless
# 7      min_entropy             500.0                5   memoryless
# 8      min_entropy             500.0                5   memoryless
# 9      min_entropy             500.0                5   memoryless
# 10     min_entropy             500.0                5   memoryless
# 11     min_entropy             500.0                5   memoryless
# 12     min_entropy             500.0                5   memoryless
# 13     min_entropy             500.0                5   memoryless
# 14     min_entropy             500.0                5   memoryless
# 15     min_entropy             500.0                5   memoryless
# 16     min_entropy             500.0                5   memoryless
# 17     min_entropy             500.0                5   memoryless
# 18     min_entropy             500.0                5   memoryless
# 19     min_entropy             500.0                5   memoryless
# 20     min_entropy             500.0                5   memoryless
# 21     min_entropy             500.0                5   memoryless
# 22     min_entropy             500.0                5   memoryless
# 23     min_entropy             500.0                5   memoryless
# 24     min_entropy             500.0                5   memoryless
#
#     process_memory  med_ent_n_transitions  inter_arrival_time  \
# 0              2.0                    1.0                 1.5
# 1              2.0                    2.0                 1.5
# 2              2.0                    3.0                 1.5
# 3              2.0                    4.0                 1.5
# 4              2.0                    5.0                 1.5
# 5              2.0                    1.0                 1.5
# 6              2.0                    2.0                 1.5
# 7              2.0                    3.0                 1.5
# 8              2.0                    4.0                 1.5
# 9              2.0                    5.0                 1.5
# 10             2.0                    1.0                 1.5
# 11             2.0                    2.0                 1.5
# 12             2.0                    3.0                 1.5
# 13             2.0                    4.0                 1.5
# 14             2.0                    5.0                 1.5
# 15             2.0                    1.0                 1.5
# 16             2.0                    2.0                 1.5
# 17             2.0                    3.0                 1.5
# 18             2.0                    4.0                 1.5
# 19             2.0                    5.0                 1.5
# 20             2.0                    1.0                 1.5
# 21             2.0                    2.0                 1.5
# 22             2.0                    3.0                 1.5
# 23             2.0                    4.0                 1.5
# 24             2.0                    5.0                 1.5
#
#     process_stability_scale  resource_availability_p  resource_availability_n  \
# 0                       0.1                      0.5                      3.0
# 1                       0.1                      0.5                      3.0
# 2                       0.1                      0.5                      3.0
# 3                       0.1                      0.5                      3.0
# 4                       0.1                      0.5                      3.0
# 5                       0.1                      0.5                      3.0
# 6                       0.1                      0.5                      3.0
# 7                       0.1                      0.5                      3.0
# 8                       0.1                      0.5                      3.0
# 9                       0.1                      0.5                      3.0
# 10                      0.1                      0.5                      3.0
# 11                      0.1                      0.5                      3.0
# 12                      0.1                      0.5                      3.0
# 13                      0.1                      0.5                      3.0
# 14                      0.1                      0.5                      3.0
# 15                      0.1                      0.5                      3.0
# 16                      0.1                      0.5                      3.0
# 17                      0.1                      0.5                      3.0
# 18                      0.1                      0.5                      3.0
# 19                      0.1                      0.5                      3.0
# 20                      0.1                      0.5                      3.0
# 21                      0.1                      0.5                      3.0
# 22                      0.1                      0.5                      3.0
# 23                      0.1                      0.5                      3.0
# 24                      0.1                      0.5                      3.0
#
#     ...  num_events  num_variants avg_tracelen  min_tracelen  max_tracelen  \
# 0   ...        2500             1          5.0             5             5
# 1   ...        2500             1          5.0             5             5
# 2   ...        2500             1          5.0             5             5
# 3   ...        2500             1          5.0             5             5
# 4   ...        2500             1          5.0             5             5
# 5   ...        2500             1          5.0             5             5
# 6   ...        2500             1          5.0             5             5
# 7   ...        2500             1          5.0             5             5
# 8   ...        2500             1          5.0             5             5
# 9   ...        2500             1          5.0             5             5
# 10  ...        2500             1          5.0             5             5
# 11  ...        2500             1          5.0             5             5
# 12  ...        2500             1          5.0             5             5
# 13  ...        2500             1          5.0             5             5
# 14  ...        2500             1          5.0             5             5
# 15  ...        2500             1          5.0             5             5
# 16  ...        2500             1          5.0             5             5
# 17  ...        2500             1          5.0             5             5
# 18  ...        2500             1          5.0             5             5
# 19  ...        2500             1          5.0             5             5
# 20  ...        2500             1          5.0             5             5
# 21  ...        2500             1          5.0             5             5
# 22  ...        2500             1          5.0             5             5
# 23  ...        2500             1          5.0             5             5
# 24  ...        2500             1          5.0             5             5
#
#     RESULT_num_events      TEST_MSE       TEST_MAE      TEST_R2    TEST_EVAR
# 0                2500  1.226527e+10   83841.876838     0.449065     0.452635
# 1                2500  1.919892e+10  106979.059103     0.408066     0.408114
# 2                2500  1.026553e+10   79802.919629     0.414731     0.420562
# 3                2500  1.407994e+10   86763.544508     0.494276     0.496035
# 4                2500  2.159694e+10  107943.948513     0.383973     0.384086
# 5                2500  6.228300e+09   61128.748261     0.532479     0.532665
# 6                2500  1.544464e+10   97845.734288     0.371027     0.373180
# 7                2500  1.117157e+10   81614.095625     0.535085     0.535342
# 8                2500  1.585873e+10  100434.117353     0.499980     0.501502
# 9                2500  1.697753e+10   99241.493093     0.335490     0.339390
# 10               2500  1.438203e+10   90348.678528     0.314262     0.321372
# 11               2500  1.191506e+10   87179.403447     0.266523     0.267017
# 12               2500  1.051690e+10   77169.992790     0.516204     0.516263
# 13               2500  1.797980e+10   98859.311010     0.318065     0.318101
# 14               2500  9.070600e+09   73197.855124     0.309834     0.315965
# 15               2500  8.321243e+09   68993.463492     0.553921     0.553998
# 16               2500  1.346262e+10   84432.988424     0.439812     0.442418
# 17               2500  1.350727e+10   88793.182879     0.286410     0.287026
# 18               2500  1.060495e+10   74187.066944     0.575643     0.576576
# 19               2500  1.330961e+10   89890.131463     0.470212     0.470829
# 20               2500  1.452813e+10   89587.809003     0.436335     0.436898
# 21               2500  1.261876e+10   84681.304854     0.350322     0.352625
# 22               2500  6.305583e+09   62697.520101     0.462218     0.463892
# 23               2500  9.491228e+09   77915.729592     0.364019     0.367913
# 24               2500  3.330608e+13  393969.901831 -1223.735178 -1223.729221
#
# [25 rows x 33 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=df, x='med_ent_n_transitions', y='TEST_R2')
sns.lineplot(data=df, x='med_ent_n_transitions', y='TEST_R2', sort=False)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create boxplot
sns.boxplot(data=df, x='med_ent_n_transitions', y='TEST_R2')

# Calculate medians and plot lines
medians = df.groupby(['med_ent_n_transitions'])['TEST_R2'].median().values
n = len(medians)
sns.lineplot(x=range(n), y=medians, sort=False)

# Set title and y-axis range
plt.title('Boxplot with Median Lines')
plt.ylim(0, 1)

plt.show()
